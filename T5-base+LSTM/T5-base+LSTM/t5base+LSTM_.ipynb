# %%
# !git clone https://github.com/Legal-NLP-EkStep/rhetorical-role-baseline.git
# Out:
# Cloning into 'rhetorical-role-baseline'...
# remote: Enumerating objects: 557, done.
# remote: Counting objects: 100% (557/557), done.
# remote: Compressing objects: 100% (242/242), done.
# remote: Total 557 (delta 305), reused 538 (delta 300), pack-reused 0
# Receiving objects: 100% (557/557), 885.87 KiB | 19.26 MiB/s, done.
# Resolving deltas: 100% (305/305), done.

# %%
# !pip install transformers[torch]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers[torch]
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 30.3 MB/s
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 64.8 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (1.21.6)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 47.4 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (4.13.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (4.64.1)
# Requirement already satisfied: torch!=1.12.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers[torch]) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers[torch]) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers[torch]) (3.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[torch]) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[torch]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[torch]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[torch]) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.24.0

# %%
# %cd /content/rhetorical-role-baseline
# !pip install -r requirements.txt
# Out:
# /content/rhetorical-role-baseline
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting allennlp==2.7.0
#   Downloading allennlp-2.7.0-py3-none-any.whl (738 kB)
#      |████████████████████████████████| 738 kB 27.2 MB/s
# Collecting appnope==0.1.2
#   Downloading appnope-0.1.2-py2.py3-none-any.whl (4.3 kB)
# Collecting argon2-cffi==21.1.0
#   Downloading argon2_cffi-21.1.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.whl (96 kB)
#      |████████████████████████████████| 96 kB 6.0 MB/s
# Collecting attrs==21.2.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.2 MB/s
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (0.2.0)
# Collecting backports.csv==1.0.7
#   Downloading backports.csv-1.0.7-py2.py3-none-any.whl (12 kB)
# Collecting base58==2.1.0
#   Downloading base58-2.1.0-py3-none-any.whl (5.6 kB)
# Collecting beautifulsoup4==4.9.3
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 69.0 MB/s
# Collecting bleach==4.1.0
#   Downloading bleach-4.1.0-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 62.2 MB/s
# Collecting blis==0.7.4
#   Downloading blis-0.7.4-cp37-cp37m-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 33.6 MB/s
# Collecting boto3==1.18.36
#   Downloading boto3-1.18.36-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 7.7 MB/s
# Collecting botocore==1.21.36
#   Downloading botocore-1.21.36-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 42.0 MB/s
# Collecting cachetools==4.2.2
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting catalogue==2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting certifi==2021.5.30
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 47.6 MB/s
# Collecting cffi==1.14.6
#   Downloading cffi-1.14.6-cp37-cp37m-manylinux1_x86_64.whl (402 kB)
#      |████████████████████████████████| 402 kB 13.2 MB/s
# Collecting chardet==4.0.0
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 21.1 MB/s
# Collecting charset-normalizer==2.0.4
#   Downloading charset_normalizer-2.0.4-py3-none-any.whl (36 kB)
# Collecting checklist==0.0.11
#   Downloading checklist-0.0.11.tar.gz (12.1 MB)
#      |████████████████████████████████| 12.1 MB 43.2 MB/s
# Collecting cheroot==8.5.2
#   Downloading cheroot-8.5.2-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 6.9 MB/s
# Collecting CherryPy==18.6.1
#   Downloading CherryPy-18.6.1-py2.py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 68.6 MB/s
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 22)) (7.1.2)
# Collecting configparser==5.0.2
#   Downloading configparser-5.0.2-py3-none-any.whl (19 kB)
# Collecting cryptography==3.4.8
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 54.3 MB/s
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting cymem==2.0.5
#   Downloading cymem-2.0.5-cp37-cp37m-manylinux2014_x86_64.whl (35 kB)
# Collecting datasets==1.11.0
#   Downloading datasets-1.11.0-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 67.7 MB/s
# Collecting debugpy==1.4.1
#   Downloading debugpy-1.4.1-cp37-cp37m-manylinux2014_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 53.3 MB/s
# Collecting decorator==5.0.9
#   Downloading decorator-5.0.9-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 30)) (0.7.1)
# Collecting dill==0.3.4
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 7.0 MB/s
# Collecting docker-pycreds==0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting entrypoints==0.3
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting fairscale==0.4.0
#   Downloading fairscale-0.4.0.tar.gz (190 kB)
#      |████████████████████████████████| 190 kB 72.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting feedparser==6.0.8
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 11.2 MB/s
# Collecting filelock==3.0.12
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting fsspec==2021.8.1
#   Downloading fsspec-2021.8.1-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 71.9 MB/s
# Collecting future==0.18.2
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 67.8 MB/s
# Collecting gitdb==4.0.7
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.0 MB/s
# Collecting GitPython==3.1.18
#   Downloading GitPython-3.1.18-py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 66.9 MB/s
# Collecting google-api-core==2.0.1
#   Downloading google_api_core-2.0.1-py2.py3-none-any.whl (92 kB)
#      |████████████████████████████████| 92 kB 564 kB/s
# Collecting google-auth==2.0.2
#   Downloading google_auth-2.0.2-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 66.4 MB/s
# Collecting google-cloud-core==2.0.0
#   Downloading google_cloud_core-2.0.0-py2.py3-none-any.whl (27 kB)
# Collecting google-cloud-storage==1.42.0
#   Downloading google_cloud_storage-1.42.0-py2.py3-none-any.whl (105 kB)
#      |████████████████████████████████| 105 kB 65.5 MB/s
# Collecting google-crc32c==1.1.2
#   Downloading google_crc32c-1.1.2-cp37-cp37m-manylinux2014_x86_64.whl (38 kB)
# Collecting google-resumable-media==2.0.2
#   Downloading google_resumable_media-2.0.2-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 5.4 MB/s
# Collecting googleapis-common-protos==1.53.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 62.2 MB/s
# Collecting h5py==3.4.0
#   Downloading h5py-3.4.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 18.6 MB/s
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Collecting idna==3.2
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 7.9 MB/s
# Collecting iniconfig==1.1.1
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting ipykernel==6.3.1
#   Downloading ipykernel-6.3.1-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 63.6 MB/s
# Collecting ipython==7.27.0
#   Downloading ipython-7.27.0-py3-none-any.whl (787 kB)
#      |████████████████████████████████| 787 kB 67.3 MB/s
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 54)) (0.2.0)
# Collecting ipywidgets==7.6.4
#   Downloading ipywidgets-7.6.4-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 72.1 MB/s
# Collecting iso-639==0.4.5
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      |████████████████████████████████| 167 kB 57.3 MB/s
# Collecting jaraco.classes==3.2.1
#   Downloading jaraco.classes-3.2.1-py3-none-any.whl (5.6 kB)
# Collecting jaraco.collections==3.4.0
#   Downloading jaraco.collections-3.4.0-py3-none-any.whl (10 kB)
# Collecting jaraco.functools==3.3.0
#   Downloading jaraco.functools-3.3.0-py3-none-any.whl (6.8 kB)
# Collecting jaraco.text==3.5.1
#   Downloading jaraco.text-3.5.1-py3-none-any.whl (8.1 kB)
# Collecting jedi==0.18.0
#   Downloading jedi-0.18.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 56.5 MB/s
# Collecting Jinja2==3.0.1
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 70.2 MB/s
# Collecting jmespath==0.10.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting joblib==1.0.1
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 74.8 MB/s
# Collecting jsonnet==0.17.0
#   Downloading jsonnet-0.17.0.tar.gz (259 kB)
#      |████████████████████████████████| 259 kB 74.7 MB/s
# Collecting jsonschema==3.2.0
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.4 MB/s
# Collecting jupyter==1.0.0
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting jupyter-client==7.0.2
#   Downloading jupyter_client-7.0.2-py3-none-any.whl (122 kB)
#      |████████████████████████████████| 122 kB 67.6 MB/s
# Collecting jupyter-console==6.4.0
#   Downloading jupyter_console-6.4.0-py3-none-any.whl (22 kB)
# Collecting jupyter-core==4.7.1
#   Downloading jupyter_core-4.7.1-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.4 MB/s
# Collecting jupyterlab-pygments==0.1.2
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting jupyterlab-widgets==1.0.1
#   Downloading jupyterlab_widgets-1.0.1-py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 68.6 MB/s
# Collecting kiwisolver==1.3.2
#   Downloading kiwisolver-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 60.8 MB/s
# Collecting lmdb==1.2.1
#   Downloading lmdb-1.2.1-cp37-cp37m-manylinux2010_x86_64.whl (299 kB)
#      |████████████████████████████████| 299 kB 66.9 MB/s
# Collecting lxml==4.6.3
#   Downloading lxml-4.6.3-cp37-cp37m-manylinux2014_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 49.4 MB/s
# Requirement already satisfied: MarkupSafe==2.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 76)) (2.0.1)
# Collecting matplotlib==3.4.3
#   Downloading matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 28.2 MB/s
# Collecting matplotlib-inline==0.1.2
#   Downloading matplotlib_inline-0.1.2-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: mistune==0.8.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 79)) (0.8.4)
# Collecting more-itertools==8.9.0
#   Downloading more_itertools-8.9.0-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 221 kB/s
# Collecting multiprocess==0.70.12.2
#   Downloading multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 65.5 MB/s
# Collecting munch==2.5.0
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting murmurhash==1.0.5
#   Downloading murmurhash-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (20 kB)
# Collecting nbclient==0.5.4
#   Downloading nbclient-0.5.4-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 5.6 MB/s
# Collecting nbconvert==6.1.0
#   Downloading nbconvert-6.1.0-py3-none-any.whl (551 kB)
#      |████████████████████████████████| 551 kB 70.4 MB/s
# Collecting nbformat==5.1.3
#   Downloading nbformat-5.1.3-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 75.4 MB/s
# Collecting nest-asyncio==1.5.1
#   Downloading nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Collecting nltk==3.6.2
#   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 56.9 MB/s
# Collecting notebook==6.4.3
#   Downloading notebook-6.4.3-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 35.2 MB/s
# Collecting numpy==1.21.2
#   Downloading numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 29.5 MB/s
# Collecting overrides==3.1.0
#   Downloading overrides-3.1.0.tar.gz (11 kB)
# Collecting packaging==21.0
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 6.1 MB/s
# Collecting pandas==1.3.2
#   Downloading pandas-1.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 23.1 MB/s
# Collecting pandocfilters==1.4.3
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting parso==0.8.2
#   Downloading parso-0.8.2-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.1 MB/s
# Collecting pathtools==0.1.2
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting pathy==0.6.0
#   Downloading pathy-0.6.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 914 kB/s
# Collecting patternfork-nosql==3.6
#   Downloading patternfork_nosql-3.6.tar.gz (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.3 MB/s
# Collecting pdfminer.six==20201018
#   Downloading pdfminer.six-20201018-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 30.9 MB/s
# Requirement already satisfied: pexpect==4.8.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 100)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 101)) (0.7.5)
# Collecting Pillow==8.3.2
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 51.0 MB/s
# Collecting pluggy==1.0.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting portend==2.7.1
#   Downloading portend-2.7.1-py3-none-any.whl (5.3 kB)
# Collecting preshed==3.0.5
#   Downloading preshed-3.0.5-cp37-cp37m-manylinux2014_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 73.5 MB/s
# Collecting prettytable==2.2.0
#   Downloading prettytable-2.2.0-py3-none-any.whl (23 kB)
# Collecting prometheus-client==0.11.0
#   Downloading prometheus_client-0.11.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.2 MB/s
# Requirement already satisfied: promise==2.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 108)) (2.3)
# Collecting prompt-toolkit==3.0.20
#   Downloading prompt_toolkit-3.0.20-py3-none-any.whl (370 kB)
#      |████████████████████████████████| 370 kB 56.6 MB/s
# Collecting protobuf==3.17.3
#   Downloading protobuf-3.17.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 65.2 MB/s
# Collecting psutil==5.8.0
#   Downloading psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296 kB)
#      |████████████████████████████████| 296 kB 56.9 MB/s
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 112)) (0.7.0)
# Collecting py==1.10.0
#   Downloading py-1.10.0-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 7.9 MB/s
# Collecting pyarrow==5.0.0
#   Downloading pyarrow-5.0.0-cp37-cp37m-manylinux2014_x86_64.whl (23.6 MB)
#      |████████████████████████████████| 23.6 MB 1.4 MB/s
# Requirement already satisfied: pyasn1==0.4.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 115)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 116)) (0.2.8)
# Collecting pycparser==2.20
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 58.3 MB/s
# Collecting pydantic==1.8.2
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 55.8 MB/s
# Collecting Pygments==2.10.0
#   Downloading Pygments-2.10.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 54.4 MB/s
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 7.3 MB/s
# Collecting pyrsistent==0.18.0
#   Downloading pyrsistent-0.18.0-cp37-cp37m-manylinux1_x86_64.whl (119 kB)
#      |████████████████████████████████| 119 kB 69.0 MB/s
# Collecting pytest==6.2.5
#   Downloading pytest-6.2.5-py3-none-any.whl (280 kB)
#      |████████████████████████████████| 280 kB 63.6 MB/s
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 123)) (2.8.2)
# Collecting python-docx==0.8.11
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 45.7 MB/s
# Collecting pytz==2021.1
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 68.6 MB/s
# Collecting PyYAML==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 65.5 MB/s
# Collecting pyzmq==22.2.1
#   Downloading pyzmq-22.2.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 64.3 MB/s
# Collecting qtconsole==5.1.1
#   Downloading qtconsole-5.1.1-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 73.4 MB/s
# Collecting QtPy==1.11.0
#   Downloading QtPy-1.11.0-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.4 MB/s
# Collecting regex==2021.8.28
#   Downloading regex-2021.8.28-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (745 kB)
#      |████████████████████████████████| 745 kB 67.7 MB/s
# Collecting requests==2.26.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.1 MB/s
# Collecting rsa==4.7.2
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting s3transfer==0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.0 MB/s
# Collecting sacremoses==0.0.45
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 66.1 MB/s
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 76.9 MB/s
# Collecting scipy==1.7.1
#   Downloading scipy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 1.3 MB/s
# Requirement already satisfied: Send2Trash==1.8.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 137)) (1.8.0)
# Collecting sentencepiece==0.1.96
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 61.0 MB/s
# Collecting sentry-sdk==1.3.1
#   Downloading sentry_sdk-1.3.1-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 61.8 MB/s
# Collecting sgmllib3k==1.0.0
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Collecting shortuuid==1.0.1
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Collecting six==1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
# Requirement already satisfied: smart-open==5.2.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 144)) (5.2.1)
# Collecting smmap==4.0.0
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: sortedcontainers==2.4.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 146)) (2.4.0)
# Collecting soupsieve==2.2.1
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Collecting spacy==3.1.2
#   Downloading spacy-3.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 43.4 MB/s
# Collecting spacy-legacy==3.0.8
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Collecting sqlitedict==1.7.0
#   Downloading sqlitedict-1.7.0.tar.gz (28 kB)
# Collecting srsly==2.4.1
#   Downloading srsly-2.4.1-cp37-cp37m-manylinux2014_x86_64.whl (456 kB)
#      |████████████████████████████████| 456 kB 63.3 MB/s
# Collecting subprocess32==3.5.4
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 8.3 MB/s
# Collecting tempora==4.1.1
#   Downloading tempora-4.1.1-py3-none-any.whl (15 kB)
# Collecting tensorboardX==2.4
#   Downloading tensorboardX-2.4-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 64.2 MB/s
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting terminado==0.11.1
#   Downloading terminado-0.11.1-py3-none-any.whl (15 kB)
# Collecting testpath==0.5.0
#   Downloading testpath-0.5.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 4.5 MB/s
# Collecting thinc==8.0.9
#   Downloading thinc-8.0.9-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (623 kB)
#      |████████████████████████████████| 623 kB 68.1 MB/s
# Collecting threadpoolctl==2.2.0
#   Downloading threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Collecting tokenizers==0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 41.6 MB/s
# Requirement already satisfied: toml==0.10.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 161)) (0.10.2)
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 2.7 kB/s
# Collecting torchvision==0.10.0
#   Downloading torchvision-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 1.3 MB/s
# Collecting tornado==6.1
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
#      |████████████████████████████████| 428 kB 69.5 MB/s
# Collecting tqdm==4.62.2
#   Downloading tqdm-4.62.2-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 6.4 MB/s
# Collecting traitlets==5.1.0
#   Downloading traitlets-5.1.0-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 13.8 MB/s
# Collecting transformers==4.9.2
#   Downloading transformers-4.9.2-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 44.7 MB/s
# Collecting typer==0.3.2
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting typing-extensions==3.10.0.2
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting urllib3==1.26.6
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 62.6 MB/s
# Collecting wandb==0.12.1
#   Downloading wandb-0.12.1-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 57.8 MB/s
# Collecting wasabi==0.8.2
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: wcwidth==0.2.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 173)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 174)) (0.5.1)
# Collecting widgetsnbextension==3.5.1
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 51.7 MB/s
# Collecting xxhash==2.0.2
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 39.9 MB/s
# Collecting zc.lockfile==2.0
#   Downloading zc.lockfile-2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue==2.0.6->-r requirements.txt (line 14)) (3.10.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets==1.11.0->-r requirements.txt (line 27)) (4.13.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core==2.0.1->-r requirements.txt (line 41)) (57.4.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py==3.4.0->-r requirements.txt (line 48)) (1.5.2)
# Collecting argcomplete>=1.12.3
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Building wheels for collected packages: checklist, fairscale, future, iso-639, jsonnet, overrides, pandocfilters, pathtools, patternfork-nosql, python-docx, sgmllib3k, sqlitedict, subprocess32, termcolor, sklearn
#   Building wheel for checklist (setup.py) ... done
#   Created wheel for checklist: filename=checklist-0.0.11-py3-none-any.whl size=12165635 sha256=f65ef4b8da94752d75b460abab9c9252b55656c7668024572c152477979b5abf
#   Stored in directory: /root/.cache/pip/wheels/6a/8a/07/6446879be434879c27671c83443727d74cecf6b630c8a24d03
#   Building wheel for fairscale (PEP 517) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.0-py3-none-any.whl size=239949 sha256=b6492cc7db3a2c86f8dac49d778d4c542b73119d5794b25d13be6d6d743a5584
#   Stored in directory: /root/.cache/pip/wheels/28/8e/a3/7a2f33ac996114b816d88e55cf1235a1e058f30211e39bd719
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491071 sha256=4c221681ffa07addb194a3d7518de25078be7c91729aae87f9e2803a3d4a262b
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for iso-639 (setup.py) ... done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=169063 sha256=7378e08a3849e31903a4b8907742ee67703352a4810c56828b4bc10f76a7d42e
#   Stored in directory: /root/.cache/pip/wheels/47/60/19/6d020fc92138ed1b113a18271e83ea4b5525fe770cb45b9a2e
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.17.0-cp37-cp37m-linux_x86_64.whl size=3388757 sha256=74edae56a7a851f9d053edcf21efbf59041c47ada3e89dc7a2b0b0657ff654ca
#   Stored in directory: /root/.cache/pip/wheels/1c/28/7e/287c6b19f7161bb03c6986a3c46b51d0d7d9a1805346634e3a
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.1.0-py3-none-any.whl size=10187 sha256=d53bc0904005c652b773a8c4f888fbe96860b0df243ab182386bee85023672ee
#   Stored in directory: /root/.cache/pip/wheels/3a/0d/38/01a9bc6e20dcfaf0a6a7b552d03137558ba1c38aea47644682
#   Building wheel for pandocfilters (setup.py) ... done
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=8006 sha256=f7620f61b1563b9287c0ff1ccffa84acfb0aae868edea5088293b1d7d063bfed
#   Stored in directory: /root/.cache/pip/wheels/42/81/34/545dc2fbf0e9137811e901108d37fc04650e81d48f97078000
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=915e095043ff4c63149ac14b25eba07ec3d5502d592424a6094be90f930613af
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for patternfork-nosql (setup.py) ... done
#   Created wheel for patternfork-nosql: filename=patternfork_nosql-3.6-py3-none-any.whl size=22332807 sha256=416a4326fc12c6cc02ca310adfd68264eb88037908758851f8223e4b119ffe1c
#   Stored in directory: /root/.cache/pip/wheels/97/72/8f/5305fe28168f93b658da9ed433b9a1d3ec90594faa0c9aaf4b
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184505 sha256=d3ace8f77a4b12cf11881dc12f038b7830a944fd963e09597a53e5d5e9599e4b
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=ab04cc38a066b8ac3f956134e10b3d4649ad70211624a4b40e051aa15496e036
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-1.7.0-py3-none-any.whl size=14391 sha256=17a5f35e4fdc803ce3d774725880495f8585df67b29a3b300cf69810b8c33925
#   Stored in directory: /root/.cache/pip/wheels/af/94/06/18c0e83e9e227da8f3582810b51f319bbfd181e508676a56c8
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6501 sha256=1e70a37dea3e170c272dd9aa312cd2dad2ba27f6d3f09e1f680798616ede1404
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4849 sha256=eb98a9452d7fc2b532f7d5caf9282c724d78ed8519c6efebebf1301d5db240f8
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2344 sha256=953af6560b654caa828bccecf65f3a35bb350db25c1133fe6ca98131939b4a38
#   Stored in directory: /root/.cache/pip/wheels/42/56/cc/4a8bf86613aafd5b7f1b310477667c1fca5c51c3ae4124a003
# Successfully built checklist fairscale future iso-639 jsonnet overrides pandocfilters pathtools patternfork-nosql python-docx sgmllib3k sqlitedict subprocess32 termcolor sklearn
# Installing collected packages: typing-extensions, traitlets, six, pyrsistent, attrs, tornado, pyzmq, pyparsing, parso, nest-asyncio, jupyter-core, jsonschema, entrypoints, Pygments, pycparser, prompt-toolkit, packaging, nbformat, matplotlib-inline, jupyter-client, jedi, decorator, testpath, pandocfilters, nbclient, more-itertools, jupyterlab-pygments, Jinja2, ipython, debugpy, cffi, bleach, argcomplete, terminado, pytz, prometheus-client, nbconvert, jaraco.functools, ipykernel, argon2-cffi, urllib3, tempora, rsa, protobuf, numpy, notebook, murmurhash, jaraco.text, jaraco.classes, idna, cymem, charset-normalizer, certifi, catalogue, cachetools, zc.lockfile, widgetsnbextension, wasabi, typer, tqdm, srsly, soupsieve, smmap, sgmllib3k, requests, regex, QtPy, pydantic, preshed, portend, lxml, jupyterlab-widgets, joblib, jmespath, jaraco.collections, googleapis-common-protos, google-auth, filelock, cryptography, cheroot, chardet, blis, tokenizers, thinc, spacy-legacy, scipy, sacremoses, qtconsole, PyYAML, python-docx, pdfminer.six, pathy, nltk, jupyter-console, ipywidgets, huggingface-hub, google-crc32c, google-api-core, gitdb, future, feedparser, dill, CherryPy, botocore, beautifulsoup4, backports.csv, xxhash, transformers, torch, threadpoolctl, subprocess32, spacy, shortuuid, sentry-sdk, s3transfer, pyarrow, py, psutil, pluggy, Pillow, patternfork-nosql, pathtools, pandas, munch, multiprocess, jupyter, iso-639, iniconfig, google-resumable-media, google-cloud-core, GitPython, fsspec, docker-pycreds, configparser, wandb, torchvision, termcolor, tensorboardX, sqlitedict, sentencepiece, scikit-learn, pytest, overrides, lmdb, kiwisolver, jsonnet, h5py, google-cloud-storage, fairscale, datasets, cycler, checklist, boto3, base58, sklearn, prettytable, matplotlib, appnope, allennlp
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: pyrsistent
#     Found existing installation: pyrsistent 0.19.2
#     Uninstalling pyrsistent-0.19.2:
#       Successfully uninstalled pyrsistent-0.19.2
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.4
#     Uninstalling tornado-6.0.4:
#       Successfully uninstalled tornado-6.0.4
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.1
#     Uninstalling pyzmq-23.2.1:
#       Successfully uninstalled pyzmq-23.2.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.3
#     Uninstalling parso-0.8.3:
#       Successfully uninstalled parso-0.8.3
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.11.2
#     Uninstalling jupyter-core-4.11.2:
#       Successfully uninstalled jupyter-core-4.11.2
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
#   Attempting uninstall: entrypoints
#     Found existing installation: entrypoints 0.4
#     Uninstalling entrypoints-0.4:
#       Successfully uninstalled entrypoints-0.4
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 2.21
#     Uninstalling pycparser-2.21:
#       Successfully uninstalled pycparser-2.21
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 2.0.10
#     Uninstalling prompt-toolkit-2.0.10:
#       Successfully uninstalled prompt-toolkit-2.0.10
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.7.0
#     Uninstalling nbformat-5.7.0:
#       Successfully uninstalled nbformat-5.7.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: testpath
#     Found existing installation: testpath 0.6.0
#     Uninstalling testpath-0.6.0:
#       Successfully uninstalled testpath-0.6.0
#   Attempting uninstall: pandocfilters
#     Found existing installation: pandocfilters 1.5.0
#     Uninstalling pandocfilters-1.5.0:
#       Successfully uninstalled pandocfilters-1.5.0
#   Attempting uninstall: more-itertools
#     Found existing installation: more-itertools 9.0.0
#     Uninstalling more-itertools-9.0.0:
#       Successfully uninstalled more-itertools-9.0.0
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.9.0
#     Uninstalling ipython-7.9.0:
#       Successfully uninstalled ipython-7.9.0
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.0.0
#     Uninstalling debugpy-1.0.0:
#       Successfully uninstalled debugpy-1.0.0
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.15.1
#     Uninstalling cffi-1.15.1:
#       Successfully uninstalled cffi-1.15.1
#   Attempting uninstall: bleach
#     Found existing installation: bleach 5.0.1
#     Uninstalling bleach-5.0.1:
#       Successfully uninstalled bleach-5.0.1
#   Attempting uninstall: terminado
#     Found existing installation: terminado 0.13.3
#     Uninstalling terminado-0.13.3:
#       Successfully uninstalled terminado-0.13.3
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.6
#     Uninstalling pytz-2022.6:
#       Successfully uninstalled pytz-2022.6
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus-client 0.15.0
#     Uninstalling prometheus-client-0.15.0:
#       Successfully uninstalled prometheus-client-0.15.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.3.4
#     Uninstalling ipykernel-5.3.4:
#       Successfully uninstalled ipykernel-5.3.4
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: notebook
#     Found existing installation: notebook 5.7.16
#     Uninstalling notebook-5.7.16:
#       Successfully uninstalled notebook-5.7.16
#   Attempting uninstall: murmurhash
#     Found existing installation: murmurhash 1.0.9
#     Uninstalling murmurhash-1.0.9:
#       Successfully uninstalled murmurhash-1.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: cymem
#     Found existing installation: cymem 2.0.7
#     Uninstalling cymem-2.0.7:
#       Successfully uninstalled cymem-2.0.7
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.1.1
#     Uninstalling charset-normalizer-2.1.1:
#       Successfully uninstalled charset-normalizer-2.1.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.9.24
#     Uninstalling certifi-2022.9.24:
#       Successfully uninstalled certifi-2022.9.24
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.2.0
#     Uninstalling cachetools-5.2.0:
#       Successfully uninstalled cachetools-5.2.0
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.1
#     Uninstalling widgetsnbextension-3.6.1:
#       Successfully uninstalled widgetsnbextension-3.6.1
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 0.10.1
#     Uninstalling wasabi-0.10.1:
#       Successfully uninstalled wasabi-0.10.1
#   Attempting uninstall: typer
#     Found existing installation: typer 0.7.0
#     Uninstalling typer-0.7.0:
#       Successfully uninstalled typer-0.7.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.5
#     Uninstalling srsly-2.4.5:
#       Successfully uninstalled srsly-2.4.5
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.6.2
#     Uninstalling regex-2022.6.2:
#       Successfully uninstalled regex-2022.6.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Uninstalling pydantic-1.10.2:
#       Successfully uninstalled pydantic-1.10.2
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.8
#     Uninstalling preshed-3.0.8:
#       Successfully uninstalled preshed-3.0.8
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.1
#     Uninstalling lxml-4.9.1:
#       Successfully uninstalled lxml-4.9.1
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.3
#     Uninstalling jupyterlab-widgets-3.0.3:
#       Successfully uninstalled jupyterlab-widgets-3.0.3
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.57.0
#     Uninstalling googleapis-common-protos-1.57.0:
#       Successfully uninstalled googleapis-common-protos-1.57.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.14.1
#     Uninstalling google-auth-2.14.1:
#       Successfully uninstalled google-auth-2.14.1
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.8.0
#     Uninstalling filelock-3.8.0:
#       Successfully uninstalled filelock-3.8.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 3.0.4
#     Uninstalling chardet-3.0.4:
#       Successfully uninstalled chardet-3.0.4
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.9
#     Uninstalling blis-0.7.9:
#       Successfully uninstalled blis-0.7.9
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.2
#     Uninstalling tokenizers-0.13.2:
#       Successfully uninstalled tokenizers-0.13.2
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.5
#     Uninstalling thinc-8.1.5:
#       Successfully uninstalled thinc-8.1.5
#   Attempting uninstall: spacy-legacy
#     Found existing installation: spacy-legacy 3.0.10
#     Uninstalling spacy-legacy-3.0.10:
#       Successfully uninstalled spacy-legacy-3.0.10
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pathy
#     Found existing installation: pathy 0.8.1
#     Uninstalling pathy-0.8.1:
#       Successfully uninstalled pathy-0.8.1
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
#   Attempting uninstall: jupyter-console
#     Found existing installation: jupyter-console 6.1.0
#     Uninstalling jupyter-console-6.1.0:
#       Successfully uninstalled jupyter-console-6.1.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.11.1
#     Uninstalling huggingface-hub-0.11.1:
#       Successfully uninstalled huggingface-hub-0.11.1
#   Attempting uninstall: google-crc32c
#     Found existing installation: google-crc32c 1.5.0
#     Uninstalling google-crc32c-1.5.0:
#       Successfully uninstalled google-crc32c-1.5.0
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.8.2
#     Uninstalling google-api-core-2.8.2:
#       Successfully uninstalled google-api-core-2.8.2
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.24.0
#     Uninstalling transformers-4.24.0:
#       Successfully uninstalled transformers-4.24.0
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.1.0
#     Uninstalling threadpoolctl-3.1.0:
#       Successfully uninstalled threadpoolctl-3.1.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.3
#     Uninstalling spacy-3.4.3:
#       Successfully uninstalled spacy-3.4.3
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 9.0.0
#     Uninstalling pyarrow-9.0.0:
#       Successfully uninstalled pyarrow-9.0.0
#   Attempting uninstall: py
#     Found existing installation: py 1.11.0
#     Uninstalling py-1.11.0:
#       Successfully uninstalled py-1.11.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 2.4.0
#     Uninstalling google-resumable-media-2.4.0:
#       Successfully uninstalled google-resumable-media-2.4.0
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 2.3.2
#     Uninstalling google-cloud-core-2.3.2:
#       Successfully uninstalled google-cloud-core-2.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.1.0
#     Uninstalling termcolor-2.1.0:
#       Successfully uninstalled termcolor-2.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Attempting uninstall: lmdb
#     Found existing installation: lmdb 0.99
#     Uninstalling lmdb-0.99:
#       Successfully uninstalled lmdb-0.99
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.4
#     Uninstalling kiwisolver-1.4.4:
#       Successfully uninstalled kiwisolver-1.4.4
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 2.5.0
#     Uninstalling google-cloud-storage-2.5.0:
#       Successfully uninstalled google-cloud-storage-2.5.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.5.0
#     Uninstalling prettytable-3.5.0:
#       Successfully uninstalled prettytable-3.5.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.9.0 which is incompatible.
# proto-plus 1.22.1 requires protobuf<5.0.0dev,>=3.19.0, but you have protobuf 3.17.3 which is incompatible.
# pandas-gbq 0.17.9 requires google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5, but you have google-api-core 2.0.1 which is incompatible.
# moviepy 0.2.3.5 requires decorator<5.0,>=4.0.2, but you have decorator 5.0.9 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=5.3.4, but you have ipykernel 6.3.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=7.9.0, but you have ipython 7.27.0 which is incompatible.
# google-colab 1.0.0 requires notebook~=5.7.16, but you have notebook 6.4.3 which is incompatible.
# google-colab 1.0.0 requires tornado~=6.0.4, but you have tornado 6.1 which is incompatible.
# google-cloud-translate 3.8.4 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0, but you have google-api-core 2.0.1 which is incompatible.
# google-cloud-translate 3.8.4 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.17.3 which is incompatible.
# google-cloud-language 2.6.1 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0, but you have google-api-core 2.0.1 which is incompatible.
# google-cloud-language 2.6.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.17.3 which is incompatible.
# google-cloud-firestore 2.7.2 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0, but you have google-api-core 2.0.1 which is incompatible.
# google-cloud-firestore 2.7.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.17.3 which is incompatible.
# google-cloud-datastore 2.9.0 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0, but you have google-api-core 2.0.1 which is incompatible.
# google-cloud-datastore 2.9.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.17.3 which is incompatible.
# google-cloud-bigquery 3.3.6 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5, but you have google-api-core 2.0.1 which is incompatible.
# google-cloud-bigquery 3.3.6 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.17.3 which is incompatible.
# google-cloud-bigquery-storage 2.16.2 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0, but you have google-api-core 2.0.1 which is incompatible.
# google-cloud-bigquery-storage 2.16.2 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.17.3 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.0.1 which is incompatible.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.1.2 which is incompatible.
# Successfully installed CherryPy-18.6.1 GitPython-3.1.18 Jinja2-3.0.1 Pillow-8.3.2 PyYAML-5.4.1 Pygments-2.10.0 QtPy-2.3.0 allennlp-2.7.0 appnope-0.1.2 argcomplete-2.0.0 argon2-cffi-21.1.0 attrs-21.2.0 backports.csv-1.0.7 base58-2.1.0 beautifulsoup4-4.9.3 bleach-4.1.0 blis-0.7.4 boto3-1.18.36 botocore-1.21.36 cachetools-4.2.2 catalogue-2.0.6 certifi-2021.5.30 cffi-1.14.6 chardet-4.0.0 charset-normalizer-2.0.4 checklist-0.0.11 cheroot-8.5.2 configparser-5.0.2 cryptography-3.4.8 cycler-0.10.0 cymem-2.0.5 datasets-1.11.0 debugpy-1.4.1 decorator-5.0.9 dill-0.3.4 docker-pycreds-0.4.0 entrypoints-0.3 fairscale-0.4.0 feedparser-6.0.8 filelock-3.0.12 fsspec-2021.8.1 future-0.18.2 gitdb-4.0.7 google-api-core-2.0.1 google-auth-2.0.2 google-cloud-core-2.0.0 google-cloud-storage-1.42.0 google-crc32c-1.1.2 google-resumable-media-2.0.2 googleapis-common-protos-1.53.0 h5py-3.4.0 huggingface-hub-0.0.12 idna-3.2 iniconfig-1.1.1 ipykernel-6.3.1 ipython-7.27.0 ipywidgets-7.6.4 iso-639-0.4.5 jaraco.classes-3.2.1 jaraco.collections-3.4.0 jaraco.functools-3.3.0 jaraco.text-3.5.1 jedi-0.18.2 jmespath-0.10.0 joblib-1.0.1 jsonnet-0.17.0 jsonschema-3.2.0 jupyter-1.0.0 jupyter-client-7.0.2 jupyter-console-6.4.0 jupyter-core-4.7.1 jupyterlab-pygments-0.1.2 jupyterlab-widgets-1.0.1 kiwisolver-1.3.2 lmdb-1.2.1 lxml-4.6.3 matplotlib-3.4.3 matplotlib-inline-0.1.2 more-itertools-8.9.0 multiprocess-0.70.12.2 munch-2.5.0 murmurhash-1.0.5 nbclient-0.5.4 nbconvert-6.1.0 nbformat-5.1.3 nest-asyncio-1.5.1 nltk-3.6.2 notebook-6.4.3 numpy-1.21.2 overrides-3.1.0 packaging-21.0 pandas-1.3.2 pandocfilters-1.4.3 parso-0.8.2 pathtools-0.1.2 pathy-0.6.0 patternfork-nosql-3.6 pdfminer.six-20201018 pluggy-1.0.0 portend-2.7.1 preshed-3.0.5 prettytable-2.2.0 prometheus-client-0.11.0 prompt-toolkit-3.0.20 protobuf-3.17.3 psutil-5.8.0 py-1.10.0 pyarrow-5.0.0 pycparser-2.20 pydantic-1.8.2 pyparsing-2.4.7 pyrsistent-0.18.0 pytest-6.2.5 python-docx-0.8.11 pytz-2021.1 pyzmq-22.2.1 qtconsole-5.4.0 regex-2021.8.28 requests-2.26.0 rsa-4.7.2 s3transfer-0.5.0 sacremoses-0.0.45 scikit-learn-0.24.2 scipy-1.7.1 sentencepiece-0.1.96 sentry-sdk-1.3.1 sgmllib3k-1.0.0 shortuuid-1.0.1 six-1.16.0 sklearn-0.0.post1 smmap-4.0.0 soupsieve-2.2.1 spacy-3.1.2 spacy-legacy-3.0.8 sqlitedict-1.7.0 srsly-2.4.1 subprocess32-3.5.4 tempora-4.1.1 tensorboardX-2.4 termcolor-1.1.0 terminado-0.11.1 testpath-0.5.0 thinc-8.0.9 threadpoolctl-2.2.0 tokenizers-0.10.3 torch-1.9.0 torchvision-0.10.0 tornado-6.1 tqdm-4.62.2 traitlets-5.1.0 transformers-4.9.2 typer-0.3.2 typing-extensions-3.10.0.2 urllib3-1.26.6 wandb-0.12.1 wasabi-0.8.2 widgetsnbextension-3.5.1 xxhash-2.0.2 zc.lockfile-2.0

# %%
# %cd /content/rhetorical-role-baseline
# !python tokenize_files.py ../train.json ../dev.json ../dev.json

# %%
# !python baseline_run.py

# %%
# !wget https://storage.googleapis.com/indianlegalbert/OPEN_SOURCED_FILES/Rhetorical_Role_Benchmark/Data/train.json
# Out:
# --2022-11-29 18:54:53--  https://storage.googleapis.com/indianlegalbert/OPEN_SOURCED_FILES/Rhetorical_Role_Benchmark/Data/train.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.200.128, 142.250.4.128, 74.125.24.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.200.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13645789 (13M) [application/json]
# Saving to: ‘train.json’
#
# train.json          100%[===================>]  13.01M  9.39MB/s    in 1.4s
#
# 2022-11-29 18:54:55 (9.39 MB/s) - ‘train.json’ saved [13645789/13645789]

# %%
# !wget https://storage.googleapis.com/indianlegalbert/OPEN_SOURCED_FILES/Rhetorical_Role_Benchmark/Data/dev.json
# Out:
# --2022-11-29 18:54:55--  https://storage.googleapis.com/indianlegalbert/OPEN_SOURCED_FILES/Rhetorical_Role_Benchmark/Data/dev.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.200.128, 142.250.4.128, 74.125.24.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.200.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1265870 (1.2M) [application/json]
# Saving to: ‘dev.json’
#
# dev.json            100%[===================>]   1.21M  1.62MB/s    in 0.7s
#
# 2022-11-29 18:54:56 (1.62 MB/s) - ‘dev.json’ saved [1265870/1265870]

# %%
import json
train = json.load(open('train.json'))
dev = json.load(open('dev.json'))

# %%
def clean_text(text):
    return text.strip()

# %%
labels_train=[]
data=[]
labels_test=[]
data_test=[]
for i in train:
  for annotations in i['annotations']:
    for results in annotations['result']:
      data.append(clean_text(results['value']['text']))
      labels_train.append(results['value']['labels'][0])
for i in dev:
  for annotations in i['annotations']:
    for results in annotations['result']:
      data_test.append(clean_text(results['value']['text']))
      labels_test.append(results['value']['labels'][0])

# %%
print(len(labels_train))
print(len(labels_test))
# Out:
# 28986
# 2890

# %%
# # for i in [1, 100, 1000, 2000, 5000]:
# #     print(data[i])
# #     print(labels_train[i])
# #     print('--' * 20)
# print(28986/245)
# Out:
# 118.31020408163265

# %%
# !pip install transformers[torch]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers[torch]
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 31.5 MB/s
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 67.9 MB/s
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 73.8 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (4.13.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (1.21.6)
# Requirement already satisfied: torch!=1.12.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from transformers[torch]) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers[torch]) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers[torch]) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers[torch]) (3.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[torch]) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[torch]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[torch]) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[torch]) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.0 tokenizers-0.13.2 transformers-4.24.0

# %%
# !pip install  sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 4.9 MB/s
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.62.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.9.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.24.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.6.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.1.96)
# Collecting huggingface-hub>=0.4.0
#   Using cached huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.10.0.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.26.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.8.28)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.10.3)
# Collecting transformers<5.0.0,>=4.6.0
#   Using cached transformers-4.24.0-py3-none-any.whl (5.5 MB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.10.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (8.3.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=5b539233b39b603203c06d7669522d4d114ae7d97f077ad93accb7061edc0bd8
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, huggingface-hub, transformers, sentence-transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.10.3
#     Uninstalling tokenizers-0.10.3:
#       Successfully uninstalled tokenizers-0.10.3
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.0.12
#     Uninstalling huggingface-hub-0.0.12:
#       Successfully uninstalled huggingface-hub-0.0.12
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.9.2
#     Uninstalling transformers-4.9.2:
#       Successfully uninstalled transformers-4.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 1.11.0 requires huggingface-hub<0.1.0, but you have huggingface-hub 0.11.1 which is incompatible.
# allennlp 2.7.0 requires transformers<4.10,>=4.1, but you have transformers 4.24.0 which is incompatible.
# Successfully installed huggingface-hub-0.11.1 sentence-transformers-2.2.2 tokenizers-0.13.2 transformers-4.24.0

# %%
from transformers import AutoTokenizer, AutoModel, AutoConfig
import numpy as np
import torch
from torch.nn.functional import normalize

# %%
# tokenizer_labse = AutoTokenizer.from_pretrained("setu4993/LaBSE")
# model_labse = AutoModel.from_pretrained("setu4993/LaBSE")

# %%
# !pip install  sentence-transformers

# %%
from sentence_transformers import SentenceTransformer

# %%
# !pip install "sagemaker>=2.69.0" "transformers==4.12.3" --upgrade

# %%
# !pip install huggingface_hub.snapshot_download

# %%
# model = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
model = SentenceTransformer('sentence-transformers/sentence-t5-large')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.02k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/670M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/461 [00:00<?, ?B/s]

# %%
# def get_embeddings(sentece):
#     tokenized = tokenizer_labse(sentece,
#                                 return_tensors="pt",
#                                 padding=True)
#     with torch.no_grad():
#         embeddings = model_labse(**tokenized)
    
#     return np.squeeze(np.array(embeddings.pooler_output))

def get_embeddings(sentence):
  return model.encode(sentence)

# %%
TRAIN_SIZE = len(labels_train)
print(TRAIN_SIZE)
# Out:
# 28986

# %%
import numpy as np
try:
    X=np.load('/content/drive/MyDrive/proj/train_Embedding (1).npy')
    y=np.load('/content/drive/MyDrive/proj/labels (1).npy')
    X_test=np.load('/content/drive/MyDrive/proj/test_Embedding (1).npy')
    y_test=np.load('/content/drive/MyDrive/proj/labels_test (1).npy')
except Exception as e:
  print(e)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
try:
    X=np.load('train_Embedding (1).npy')
    y=np.load('labels (1).npy')
except:
    X = []
    labels = list(set(labels_train))
    y = []
    progress = 0
    for sentence, label in zip(data[:TRAIN_SIZE],
                            labels_train[:TRAIN_SIZE]):
        X.append(get_embeddings(sentence))
        y.append(labels.index(label))
        progress += 1
        # print(progress)
        if progress % 500 == 0:
            print('Progress Percent = {}%'.format(100 * progress / TRAIN_SIZE))

# TEST_SIZE = len(labels_test)
# print(TEST_SIZE)

try:
    X_test=np.load('test_Embedding (1).npy')
    y_test=np.load('labels_test (1).npy')
except:
    X_test = []
    labels = list(set(labels_test))
    y_test = []
    progress = 0
    for sentence, label in zip(data[:TEST_SIZE],
                            labels_train[:TEST_SIZE]):
        X_test.append(get_embeddings(sentence))
        y_test.append(labels.index(label))
        progress += 1
        # print(progress)
        if progress % 500 == 0:
            print('Progress Percent = {}%'.format(100 * progress / TEST_SIZE))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c967d425ec43> in <module>
#       1 try:
# ----> 2     X=np.load('train_Embedding (1).npy')
#       3     y=np.load('labels (1).npy')
#
# NameError: name 'np' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c967d425ec43> in <module>
#       4 except:
#       5     X = []
# ----> 6     labels = list(set(labels_train))
#       7     y = []
#       8     progress = 0
#
# NameError: name 'labels_train' is not defined

# %%
# !ls
# Out:
# baseline_run.py		    LICENSE
# batch_creator.py	    models.py
# bucketing.py		    multitask_run.py
# clusters		    multitask_run_sep_layers.py
# compile_generic_dataset.py  README.md
# convert_art.py		    requirements_colab.txt
# convert_jsonl_to_csv.py     requirements.txt
# convert_to_jsonl.py	    Rhetorical_Roles_Structure.png
# covert_dri.py		    semantic_relatedness_labels.ipynb
# data_prep.py		    silhouette_analysis_label_clusters.ipynb
# dataset_reader.py	    SummaryGeneration.py
# datasets		    task.py
# dev.json		    tokenize_files.py
# eval.py			    torchserve
# eval_run.py		    train.json
# evaluation.py		    train.py
# gpu_executor.py		    transfer_run.py
# infer_data_prep.py	    use_cases
# infer_new.py		    utils.py
# jsonl_to_txt.py

# %%
with open('train_Embedding (1).npy', 'wb') as f:
    np.save(f, X)
with open('labels (1).npy', 'wb') as f:
    np.save(f, y)

with open('test_Embedding (1).npy', 'wb') as f:
    np.save(f, X_test)
with open('labels_test (1).npy', 'wb') as f:
    np.save(f, y_test)

# %%
X_test = np.array(X)
y_test = np.array(y)
print(X_test.shape, y_test.shape)
# Out:
# (28986, 768) (28986,)

# %%
import torch.nn.functional as F
import torch.nn as nn
import torch
class LSTM_Model(nn.Module):

    def __init__(self):
        super(LSTM_Model, self).__init__()
      
        self.lstm = torch.nn.LSTM(input_size=768, hidden_size=64,
                                                             num_layers=3, batch_first=True, bidirectional=True)
        self.output_layer = nn.Linear(128,13)

    def forward(self, batch):
        lstm_out, _ = self.lstm(batch)
        # lstm_out, _ = self.lstm(embeds)
        # print(lstm_out.shape)
        tag_space = self.output_layer(lstm_out)
        tag_scores = F.softmax(tag_space, dim=1)
        return tag_scores

# %%
model = LSTM_Model()

# %%
print(model)
# Out:
# LSTM_Model(
#   (lstm): LSTM(768, 64, num_layers=3, batch_first=True, bidirectional=True)
#   (output_layer): Linear(in_features=128, out_features=13, bias=True)
# )

# %%
len(list(model.parameters()))
# Out:
# 26

# %%
for i in range(len(list(model.parameters()))):
    print(list(model.parameters())[i].size())
# Out:
# torch.Size([256, 768])
# torch.Size([256, 64])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256, 768])
# torch.Size([256, 64])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256, 128])
# torch.Size([256, 64])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256, 128])
# torch.Size([256, 64])
# torch.Size([256])
# torch.Size([256])
# torch.Size([13, 100])
# torch.Size([13])

# %%
# import numpy as np

# try:
#     X=np.load('train_Embedding (1).npy')
#     y=np.load('labels (1).npy')
#     X_test = np.load('test_Embedding (1).npy')
#     y_test = np.load('labels_test (1).npy')
# except Exception as e:
#   print(e)

# %%
import torch
train_data = []
test_data = []
import random
for i in range(len(X)):
  # #  print((X[i].shape))
  #   y_0 = np.zeros(13)
  #   y_0[y[i]]=1
    train_data.append([X[i], y[i]])
# from sklearn.model_selection import train_test_split
for i in range(len(X_test)):
  # #  print((X[i].shape))
  #  y_0 = np.zeros(13)
  #  y_0[y_test[i]]=1
   test_data.append([X_test[i], y_test[i]])

trainloader = torch.utils.data.DataLoader(train_data, shuffle=False, batch_size=64)
testloader = torch.utils.data.DataLoader(test_data, shuffle=False, batch_size=64)

# %%
total=0
correct =0
for i, (input, labels) in enumerate(testloader):
  output = model(input)
  _, predicted = torch.max(output.data, 1)
  
  total += labels.size(0)
  correct += (predicted == labels).sum()

print(correct/total)
  # print(output)
# Out:
# tensor(0.0381)

# %%
num_epochs = 10
# iter = 0
import torch
learning_rate = 0.1
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  
for epoch in range(num_epochs):
    for i, (input, labels) in enumerate(trainloader):
        # input = input.view(-1, seq_dim, input_dim).requires_grad_()
        optimizer.zero_grad()
        outputs = model(input)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
    correct = 0
    total = 0
    for input, labels in testloader:
      outputs = model(input)
      _, predicted = torch.max(outputs.data, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum()

    accuracy = 100 * correct / total

    print('Epoch: {}. Loss: {}. Accuracy: {}'.format(epoch, loss.item(), accuracy))
# Out:
# Epoch: 0. Loss: 2.206331729888916. Accuracy: 39.23875427246094
# Epoch: 1. Loss: 2.206331729888916. Accuracy: 39.23875427246094
# Epoch: 2. Loss: 2.206331729888916. Accuracy: 39.23875427246094
# Epoch: 3. Loss: 2.206331729888916. Accuracy: 39.23875427246094
# Epoch: 4. Loss: 2.206331729888916. Accuracy: 39.23875427246094
# Epoch: 5. Loss: 2.206331729888916. Accuracy: 39.23875427246094
# Epoch: 6. Loss: 2.206331729888916. Accuracy: 39.23875427246094
# Epoch: 7. Loss: 2.206331729888916. Accuracy: 39.23875427246094
# Epoch: 8. Loss: 2.206331729888916. Accuracy: 39.23875427246094
# Epoch: 9. Loss: 2.206331729888916. Accuracy: 39.23875427246094

# %%
for input, labels in testloader:
      outputs = model(input)
      _, predicted = torch.max(outputs.data, 1)
      print(predicted)

# %%
print(labels)
# Out:
# tensor([ 8,  4, 11,  6,  6,  6,  6, 12,  6,  6,  8,  0,  4, 12, 11,  4,  4,  2,
#          6, 12,  6,  9, 11,  0,  9,  4,  6,  7, 11,  6,  7,  1, 11,  6,  8,  6,
#          6,  9,  6,  1,  4,  3,  6,  6,  9,  6,  4, 12,  6,  4, 12,  4, 12,  4,
#          4,  0,  6,  4])

# %%
import plda

# %%
PLDA_classifier = plda.Classifier()
PLDA_classifier.fit_model(np.array(X),
                          np.array(y))

# %%
from keras.layers import Dense, Input, LSTM, Dropout, Bidirectional
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.normalization import BatchNormalization
from keras.layers.embeddings import Embedding
from keras.layers.merge import concatenate
from keras.models import load_model
from keras.models import Model

# %%
model = Sequential()
model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X.shape[1]))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(13, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

epochs = 5
batch_size = 64

history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size,validation_split=0.1,callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])

# %%
def predict_doc(query):
    query_embedding = get_embeddings(query)
    predictions, log_p_predictions = PLDA_classifier.predict(query_embedding)
    return labels[predictions]

# %%
labels_all_dev=[]
data_dev=[]

for i in dev:
  for annotations in i['annotations']:
    for results in annotations['result']:
      data_dev.append(clean_text(results['value']['text']))
      labels_all_dev.append(results['value']['labels'][0])

# %%
def predict_doc_at(query):
    query_embedding = get_embeddings(query)
    predictions, log_p_predictions = PLDA_classifier.predict(query_embedding)
    
    predictions = labels[predictions]
    return predictions

# %%
preds_dev=[]
for query in data_dev:
    preds = predict_doc_at(query)
    preds_dev.append(preds)

# %%
from sklearn.metrics import f1_score

# %%
f1score=f1_score(labels_all_dev, preds_dev, average="macro")

# %%
f1score
# Out:
# 0.4166959405717767

# %%
matches=0
all=0
for i,j in zip(labels_all_dev, preds_dev):
  if i==j:
    matches+=1
  else:
    print("i: "+i)
    print("j: "+ j)
    print("--------------")
  all+=1
# Out:
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: NONE
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RATIO
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: STA
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: RPC
# --------------
# i: FAC
# j: RPC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: RLC
# j: ISSUE
# --------------
# i: ARG_PETITIONER
# j: RPC
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: RPC
# j: RATIO
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: RLC
# j: FAC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: RLC
# j: RATIO
# --------------
# i: RLC
# j: PRE_RELIED
# --------------
# i: RLC
# j: PRE_RELIED
# --------------
# i: RLC
# j: RATIO
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: RATIO
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: RATIO
# --------------
# i: RLC
# j: RATIO
# --------------
# i: RLC
# j: RATIO
# --------------
# i: RLC
# j: PRE_RELIED
# --------------
# i: RLC
# j: PRE_RELIED
# --------------
# i: RLC
# j: RATIO
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: PRE_RELIED
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: PRE_RELIED
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: PRE_RELIED
# --------------
# i: RLC
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RPC
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: NONE
# j: PREAMBLE
# --------------
# i: NONE
# j: FAC
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: PRE_RELIED
# j: STA
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: PRE_RELIED
# j: FAC
# --------------
# i: PRE_RELIED
# j: RLC
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: FAC
# --------------
# i: PRE_RELIED
# j: FAC
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: PRE_RELIED
# j: ARG_PETITIONER
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: PRE_RELIED
# j: ISSUE
# --------------
# i: PRE_RELIED
# j: ISSUE
# --------------
# i: PRE_RELIED
# j: ISSUE
# --------------
# i: PRE_RELIED
# j: ISSUE
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: ARG_PETITIONER
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: PRE_NOT_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: ISSUE
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: STA
# --------------
# i: RLC
# j: STA
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: FAC
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: STA
# --------------
# i: RLC
# j: STA
# --------------
# i: RLC
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: PRE_RELIED
# j: ARG_PETITIONER
# --------------
# i: PRE_RELIED
# j: STA
# --------------
# i: PRE_RELIED
# j: STA
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: PRE_RELIED
# j: RLC
# --------------
# i: PRE_RELIED
# j: FAC
# --------------
# i: PRE_RELIED
# j: ISSUE
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: PRE_RELIED
# j: STA
# --------------
# i: PRE_RELIED
# j: ARG_PETITIONER
# --------------
# i: PRE_RELIED
# j: ARG_PETITIONER
# --------------
# i: STA
# j: FAC
# --------------
# i: STA
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: RPC
# j: RATIO
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RPC
# --------------
# i: PREAMBLE
# j: RPC
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: ARG_RESPONDENT
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: FAC
# j: NONE
# --------------
# i: FAC
# j: RLC
# --------------
# i: RLC
# j: FAC
# --------------
# i: RLC
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: PRE_RELIED
# j: RPC
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: RPC
# --------------
# i: NONE
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RPC
# --------------
# i: RATIO
# j: RPC
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: RATIO
# j: RPC
# --------------
# i: NONE
# j: RATIO
# --------------
# i: RPC
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: RATIO
# j: RPC
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: RLC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: RLC
# j: ARG_RESPONDENT
# --------------
# i: RLC
# j: FAC
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: RPC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: RPC
# j: ANALYSIS
# --------------
# i: RPC
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ARG_RESPONDENT
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: ARG_RESPONDENT
# --------------
# i: PREAMBLE
# j: ARG_RESPONDENT
# --------------
# i: PREAMBLE
# j: ARG_RESPONDENT
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: RLC
# j: FAC
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: PRE_NOT_RELIED
# --------------
# i: RLC
# j: FAC
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: RPC
# j: PRE_NOT_RELIED
# --------------
# i: RPC
# j: FAC
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: PRE_NOT_RELIED
# --------------
# i: RLC
# j: FAC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: RLC
# j: ARG_RESPONDENT
# --------------
# i: RLC
# j: FAC
# --------------
# i: RLC
# j: ARG_RESPONDENT
# --------------
# i: RLC
# j: FAC
# --------------
# i: FAC
# j: ISSUE
# --------------
# i: FAC
# j: ISSUE
# --------------
# i: FAC
# j: ISSUE
# --------------
# i: FAC
# j: ISSUE
# --------------
# i: FAC
# j: ISSUE
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: NONE
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: ANALYSIS
# --------------
# i: ARG_PETITIONER
# j: ANALYSIS
# --------------
# i: ARG_PETITIONER
# j: ANALYSIS
# --------------
# i: ARG_RESPONDENT
# j: ARG_PETITIONER
# --------------
# i: ARG_RESPONDENT
# j: ANALYSIS
# --------------
# i: ARG_RESPONDENT
# j: ANALYSIS
# --------------
# i: ARG_RESPONDENT
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ARG_PETITIONER
# j: PRE_NOT_RELIED
# --------------
# i: ARG_PETITIONER
# j: STA
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: PRE_NOT_RELIED
# j: RATIO
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: RATIO
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: NONE
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_RESPONDENT
# j: FAC
# --------------
# i: ARG_RESPONDENT
# j: FAC
# --------------
# i: ARG_RESPONDENT
# j: RATIO
# --------------
# i: ARG_RESPONDENT
# j: ISSUE
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RPC
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: RATIO
# j: RPC
# --------------
# i: RATIO
# j: RPC
# --------------
# i: RPC
# j: PREAMBLE
# --------------
# i: RPC
# j: ANALYSIS
# --------------
# i: NONE
# j: PREAMBLE
# --------------
# i: NONE
# j: ANALYSIS
# --------------
# i: NONE
# j: ANALYSIS
# --------------
# i: NONE
# j: ANALYSIS
# --------------
# i: NONE
# j: ANALYSIS
# --------------
# i: NONE
# j: STA
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: ARG_RESPONDENT
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: PRE_NOT_RELIED
# --------------
# i: FAC
# j: PRE_NOT_RELIED
# --------------
# i: FAC
# j: PREAMBLE
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: RLC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: RPC
# j: RATIO
# --------------
# i: NONE
# j: RPC
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: STA
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: RATIO
# j: PRE_RELIED
# --------------
# i: RATIO
# j: PRE_NOT_RELIED
# --------------
# i: RATIO
# j: RPC
# --------------
# i: RATIO
# j: FAC
# --------------
# i: RATIO
# j: FAC
# --------------
# i: RATIO
# j: RPC
# --------------
# i: RPC
# j: RLC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: FAC
# j: PREAMBLE
# --------------
# i: FAC
# j: ISSUE
# --------------
# i: RLC
# j: FAC
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: ISSUE
# --------------
# i: FAC
# j: STA
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RATIO
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: RLC
# j: PRE_RELIED
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: RATIO
# j: RLC
# --------------
# i: RATIO
# j: PRE_RELIED
# --------------
# i: RATIO
# j: RLC
# --------------
# i: RPC
# j: RATIO
# --------------
# i: FAC
# j: RPC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RPC
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: RATIO
# j: FAC
# --------------
# i: RATIO
# j: FAC
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ISSUE
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: PREAMBLE
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: NONE
# j: RPC
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: RATIO
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: RPC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: RATIO
# j: FAC
# --------------
# i: RPC
# j: RATIO
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: RPC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: NONE
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: PRE_RELIED
# j: RLC
# --------------
# i: PRE_RELIED
# j: PREAMBLE
# --------------
# i: RPC
# j: RATIO
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: ARG_RESPONDENT
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_NOT_RELIED
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: ARG_RESPONDENT
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: ISSUE
# j: PREAMBLE
# --------------
# i: ISSUE
# j: PRE_RELIED
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: PRE_RELIED
# j: STA
# --------------
# i: PRE_RELIED
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: RATIO
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: RATIO
# j: PRE_RELIED
# --------------
# i: RPC
# j: ARG_PETITIONER
# --------------
# i: RPC
# j: RATIO
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: NONE
# j: FAC
# --------------
# i: FAC
# j: NONE
# --------------
# i: RLC
# j: PREAMBLE
# --------------
# i: FAC
# j: RATIO
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RATIO
# --------------
# i: FAC
# j: RPC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: PRE_NOT_RELIED
# j: ARG_PETITIONER
# --------------
# i: PRE_NOT_RELIED
# j: PRE_RELIED
# --------------
# i: PRE_NOT_RELIED
# j: PRE_RELIED
# --------------
# i: PRE_NOT_RELIED
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: PRE_NOT_RELIED
# j: FAC
# --------------
# i: PRE_NOT_RELIED
# j: PRE_RELIED
# --------------
# i: PRE_NOT_RELIED
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: PRE_NOT_RELIED
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: RPC
# --------------
# i: FAC
# j: PREAMBLE
# --------------
# i: ISSUE
# j: PRE_RELIED
# --------------
# i: FAC
# j: RPC
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: RLC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: PRE_NOT_RELIED
# j: ARG_PETITIONER
# --------------
# i: PRE_NOT_RELIED
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: RATIO
# j: PRE_RELIED
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: RPC
# j: RLC
# --------------
# i: NONE
# j: RPC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: PRE_NOT_RELIED
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: ISSUE
# j: ANALYSIS
# --------------
# i: NONE
# j: ANALYSIS
# --------------
# i: FAC
# j: PREAMBLE
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: NONE
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: PREAMBLE
# --------------
# i: FAC
# j: PRE_NOT_RELIED
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: STA
# --------------
# i: FAC
# j: STA
# --------------
# i: FAC
# j: STA
# --------------
# i: FAC
# j: STA
# --------------
# i: FAC
# j: STA
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: PRE_RELIED
# --------------
# i: ARG_PETITIONER
# j: PRE_NOT_RELIED
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: PRE_NOT_RELIED
# --------------
# i: ARG_PETITIONER
# j: PRE_NOT_RELIED
# --------------
# i: ARG_PETITIONER
# j: PRE_NOT_RELIED
# --------------
# i: ARG_PETITIONER
# j: PRE_RELIED
# --------------
# i: ARG_PETITIONER
# j: PRE_RELIED
# --------------
# i: ARG_PETITIONER
# j: STA
# --------------
# i: ARG_PETITIONER
# j: PRE_NOT_RELIED
# --------------
# i: ARG_PETITIONER
# j: PRE_RELIED
# --------------
# i: ARG_PETITIONER
# j: PRE_RELIED
# --------------
# i: ARG_PETITIONER
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: RLC
# --------------
# i: ARG_PETITIONER
# j: ANALYSIS
# --------------
# i: ARG_PETITIONER
# j: ANALYSIS
# --------------
# i: ARG_PETITIONER
# j: ANALYSIS
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: ANALYSIS
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_RESPONDENT
# j: ARG_PETITIONER
# --------------
# i: ARG_RESPONDENT
# j: ANALYSIS
# --------------
# i: ARG_RESPONDENT
# j: ANALYSIS
# --------------
# i: ARG_RESPONDENT
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: NONE
# j: RPC
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: NONE
# j: ARG_RESPONDENT
# --------------
# i: NONE
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ISSUE
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: RATIO
# j: ARG_RESPONDENT
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: ISSUE
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: NONE
# j: RPC
# --------------
# i: NONE
# j: RATIO
# --------------
# i: FAC
# j: RLC
# --------------
# i: RLC
# j: FAC
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: RLC
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_RESPONDENT
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: RPC
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: PRE_RELIED
# j: FAC
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: RPC
# j: ANALYSIS
# --------------
# i: RATIO
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: PRE_NOT_RELIED
# --------------
# i: FAC
# j: PREAMBLE
# --------------
# i: FAC
# j: RLC
# --------------
# i: ARG_PETITIONER
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: PRE_NOT_RELIED
# --------------
# i: ARG_PETITIONER
# j: PREAMBLE
# --------------
# i: ARG_RESPONDENT
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: PRE_RELIED
# j: ARG_RESPONDENT
# --------------
# i: PRE_RELIED
# j: STA
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: RPC
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: NONE
# j: RPC
# --------------
# i: PREAMBLE
# j: PRE_NOT_RELIED
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: RLC
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: STA
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: FAC
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: RATIO
# --------------
# i: PREAMBLE
# j: PRE_NOT_RELIED
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: PREAMBLE
# j: ARG_PETITIONER
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: ANALYSIS
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: FAC
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: RLC
# j: FAC
# --------------
# i: RLC
# j: FAC
# --------------
# i: RLC
# j: ARG_RESPONDENT
# --------------
# i: RLC
# j: RATIO
# --------------
# i: RLC
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ARG_RESPONDENT
# j: ARG_PETITIONER
# --------------
# i: ARG_RESPONDENT
# j: FAC
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: STA
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: PREAMBLE
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: PRE_RELIED
# j: FAC
# --------------
# i: PRE_RELIED
# j: PREAMBLE
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: ARG_PETITIONER
# --------------
# i: PRE_RELIED
# j: FAC
# --------------
# i: PRE_RELIED
# j: FAC
# --------------
# i: PRE_RELIED
# j: FAC
# --------------
# i: PRE_RELIED
# j: RLC
# --------------
# i: PRE_RELIED
# j: ANALYSIS
# --------------
# i: PRE_RELIED
# j: RLC
# --------------
# i: PRE_RELIED
# j: ARG_PETITIONER
# --------------
# i: PRE_RELIED
# j: ARG_RESPONDENT
# --------------
# i: PRE_RELIED
# j: STA
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: PRE_RELIED
# j: PRE_NOT_RELIED
# --------------
# i: NONE
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RLC
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: FAC
# j: ARG_RESPONDENT
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: NONE
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: NONE
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: ISSUE
# --------------
# i: ARG_RESPONDENT
# j: ANALYSIS
# --------------
# i: ARG_RESPONDENT
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: RLC
# j: FAC
# --------------
# i: RLC
# j: RPC
# --------------
# i: RLC
# j: ANALYSIS
# --------------
# i: RLC
# j: FAC
# --------------
# i: RLC
# j: FAC
# --------------
# i: RLC
# j: RPC
# --------------
# i: RLC
# j: FAC
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ARG_PETITIONER
# j: ARG_RESPONDENT
# --------------
# i: ARG_PETITIONER
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ARG_PETITIONER
# j: ANALYSIS
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: RATIO
# j: ANALYSIS
# --------------
# i: RPC
# j: RATIO
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: PREAMBLE
# j: NONE
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: ARG_RESPONDENT
# j: FAC
# --------------
# i: ARG_RESPONDENT
# j: FAC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: FAC
# j: RLC
# --------------
# i: FAC
# j: ANALYSIS
# --------------
# i: ARG_RESPONDENT
# j: ARG_PETITIONER
# --------------
# i: ARG_RESPONDENT
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: PREAMBLE
# j: PRE_RELIED
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: FAC
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: PRE_RELIED
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: ARG_PETITIONER
# --------------
# i: ANALYSIS
# j: FAC
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: RATIO
# --------------
# i: ANALYSIS
# j: PRE_NOT_RELIED
# --------------
# i: ARG_PETITIONER
# j: RATIO
# --------------
# i: PRE_RELIED
# j: RATIO
# --------------
# i: ANALYSIS
# j: ARG_RESPONDENT
# --------------
# i: RPC
# j: PRE_NOT_RELIED
# --------------
# i: RPC
# j: RATIO
# --------------

# %%
prec=matches/all

# %%
prec
# Out:
# 0.5

# %%
# def predict_doc_at_cosine(query):
#     query_embedding = get_embeddings(query)
#     predictions = PLDA_classifier.predict(query_embedding)
    
#     predictions = labels[predictions]
#     return predictions

# %%
# preds_dev_cosine=[]
# for query in data_dev:
#     preds = predict_doc_at(query)
#     preds_dev_cosine.append(preds)

# %%
from sklearn.metrics.pairwise import cosine_similarity
from numpy.core.fromnumeric import argmax

# %%
# !conda install -c conda-forge faiss-gpu cudatoolkit=10.1 -y

# %%
import faiss
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
nclusters=len(labels)
print(nclusters)
dimension=X.shape[1]
num_vectors=X.shape[0]
print(dimension)
print(num_vectors)
# Out:
# 13
# 768
# 28986

# %%
quantiser = faiss.IndexFlatL2(dimension)  
index = faiss.IndexIVFFlat(quantiser, dimension, nclusters,faiss.METRIC_L2)

# %%
print(index.is_trained)   # False
index.train(X)  # train on the database vectors
print(index.ntotal)   # 0
index.add(X)   # add the vectors and update the index
print(index.is_trained)  # True
print(index.ntotal)
# Out:
# False
# 0
# True
# 28986

# %%
nprobe = 7  # find 3 most similar clusters

k = 1  # return 1 nearest neighbours
 

# distances, indices = index.search(query_vectors, k)

# %%
try:
  if embs_dev is None:

    embs_dev=[]

    for i in data_dev:
      embs_dev.append(get_embeddings(i))
except:
  embs_dev=[]

  for i in data_dev:
    embs_dev.append(get_embeddings(i))

# %%
embs_dev=np.array(embs_dev)
embs_dev.shape
# Out:
# (2890, 768)

# %%
distances, indices = index.search(embs_dev, k)

# %%
# print(distances)
# print(indices)

# %%
indices.shape
# Out:
# (2890, 1)

# %%
preds_cos=[]
for i in indices:
    preds_cos.append(labels[y[i[0]]])

# %%
# preds_cos=[]
# # que_scores=[]
# progress=0
# dev_size=len(data_dev)

# embs_dev=[]

# for i in data_dev:
#   embs_dev.append(get_embeddings(i))

# print("embeddings calculated")
# for emb_dev in embs_dev:
#   emb_score=[]
#   for emb in X:
#     emb_score.append(cosine_similarity(emb.reshape(1, -1),emb_dev.reshape(1, -1))[0][0])
#   preds_cos.append(labels[y[argmax(emb_score)]]) 
#     # if y[argmax(emb_score)]!=10:
#     # print(argmax(emb_score))
#   progress += 1
#   if progress % 500 == 0:
#       print('Progress Percent = {}%'.format(100 * progress / dev_size))

# %%
from sklearn.metrics import f1_score
f1score=f1_score(labels_all_dev, preds_cos, average="macro")

# %%
f1score
# Out:
# 0.3524619251870554

# %%
matches=0
all=0
for i,j in zip(labels_all_dev, preds_cos):
  if i==j:
    matches+=1
  # else:
  #   print("i: "+i)
  #   print("j: "+ j)
  #   print("--------------")
  all+=1

# %%
prec=matches/all

# %%
prec
# Out:
# 0.4806228373702422

# %%
# !pip install gradio==2.6.0
# import gradio as gr
# import requests
# import json

# !pip install --upgrade spacy
# !pip install allennlp
# !pip install --upgrade google-cloud-storage
# !pip install --upgrade google-api-core
# !pip install --upgrade google-auth
# !pip install --upgrade google-cloud-core

# !git clone https://github.com/Legal-NLP-EkStep/rhetorical-role-baseline.git
# #!pip install -r rhetorical-role-baseline/requirements_colab.txt
# !python -m spacy download en_core_web_trf
# !pip install --upgrade huggingface-hub

# %cd rhetorical-role-baseline
# ######## download model file
# model_url = 'https://storage.googleapis.com/indianlegalbert/OPEN_SOURCED_FILES/Rhetorical_Role_Benchmark/Model/model.pt'
# model = requests.get(model_url).content
# with open("datasets/model.pt", "wb") as file:
#     file.write(model)

# from data_prep import split_preamble_judgement
# from SummaryGeneration import SummaryGeneration
# def concatenate_text_by_rhetorical_role(annotation_list):
#     #### concatenate text for each rhetorical role
#     rhetorical_rolewise_text = {} # keys are rhetorical roles and value is concatenated text
#     for annotation in annotation_list:
#       sent_role = annotation['value']['labels'][0]
#       sent_txt = annotation['value']['text'].strip()
#       if rhetorical_rolewise_text.get(sent_role) is None:
#         rhetorical_rolewise_text[sent_role] = sent_txt
#       else:
#         if not rhetorical_rolewise_text[sent_role].endswith('.'):
#           rhetorical_rolewise_text[sent_role] = rhetorical_rolewise_text[sent_role] + '. '+ sent_txt
#         else:
#           rhetorical_rolewise_text[sent_role] = rhetorical_rolewise_text[sent_role] + ' '+ sent_txt
#     return rhetorical_rolewise_text

# def predict_rhetorical_roles_and_create_summary(input_txt):

#     if input_txt == '''                                                         REPORTABLE\n\n  IN THE SUPREME COURT OF INDIA\n CRIMINAL APPELLATE JURISDICTION\n\nCRIMINAL APPEAL NO. 1053 OF 2016\n\nNARESH KUMAR alias NITU                            ..........APPELLANT\n                                                   ......RESPONDENT\n                                           Versus\nSTATE OF HIMACHAL PRADESH\n\n                                       JUDGMENT\n NAVIN SINHA, J.\n The acquittal of the appellant by the Special Judge, Shimla in Sessions Trial No.7-S/7/2012, from the charge under Sections 20 and 61 of the Narcotic Drugs and Psychotropic Substances Act, 1985 (hereinafter referred as `the Act') has been reversed by the High Court. The appellant has been sentenced to fifteen years imprisonment and fine of Rs.2,00,000/-. Thus the present appeal.\n 2. The appellant is stated to have been apprehended at Majhotli, by the police party, on suspicion, at about 6.15 A.M.\nafter he disembarked from the State public transport bus going from Nerwa to Chamunda. Two kilograms of Charas is stated to have been recovered from a bag in his possession in presence of PW-2, Sita Ram an independent witness. DW-1 Shayam Singh, the depot in-charge at Nerwa, and DW-2 Khem Raj, the conductor of the bus in question were examined as defence witnesses.\n 3. After consideration of the entirety of the evidence, particularly that of PW-2 and DW-2, and also noticing that PW-1, Constable Rakesh Kumar, an eye-witness to the incident, had not been mentioned as a witness in the seizure memo Exhibit PW-1/B, the Special Judge opined that two theories had emerged with regard to the accusations against the appellant. The appellant was acquitted, giving him the benefit of doubt.\n 4. The High Court reversed the acquittal, holding that PW-2 had admitted his signatures on Exhibit PW-1/B, the bag along with the narcotic, Ex.PW-2/A seal impression, Ex.PW-2/D the arrest memo and the Ex.PW-2/E personal search memo. No complaint had been lodged by the witness that he had been compelled by the police to sign the documents under pressure.\nThe statements of the official witnesses, PW-1 Rakesh Kumar and PW-6 Head Constable Parmanand, were trustworthy, inspiring confidence, and could not be rejected only on the ground that they were police personnel. Any discrepancy with regard to distance and travelling time between Nerwa and Majhotli could be attributed to memory loss with passage of time, and was not required to be with mathematical precision. The time with regard to purchase of bus ticket had not been established.\n 5. Learned counsel for the appellant submits that he has been falsely implicated. He was deboarded from the bus at Chopal after it arrived from Majhotli and the narcotics planted on him. There had been no recovery from him. The bus ticket evidently reveals that he boarded the bus at 6:51 A.M. The question of his being apprehended at 6:15 A.M. simply does not arise. The road distance from Nerwa to Majhotli was 26 kms. as deposed by DW-1. In the hills, it would have taken the bus at least one hour or more, to cover this distance. The bus could not have reached Majhotli till 8:00 A.M. or thereafter. PW-2, the independent witness, deposed that he was stopped by the police at about 10.30 A.M. at Majhotli and after checking his motor cycle papers was allowed to leave. He was called to the Police Station at 1.00 P.M. and asked to put his signatures on certain documents. The witness denied any search, seizure and recovery from the appellant in his presence. If an independent witness was available, and relied upon by the prosecution, his evidence could not be discarded without reason, to hold that the police version was the truth. Additional submissions were made with regard to non-compliance with Section 50 of the Act, as there was personal search also, and that the complainant himself could not be the investigating officer. Reliance was placed on Basappa vs. State of Karnataka, 2014 (5) SCC 154 that if two views were possible, the acquittal ought not to have been interfered with in appeal.\n 6. We have considered the submissions on behalf of the parties, and also examined the evidence and other materials on record.\n 7. The public bus, on which the appellant was traveling, was going from Nerwa to Chamunda. The ticket issued to the appellant Exhibit DX, proved by the bus Conductor DW-2, bears the time of issuance 6.51 A.M., visible to the naked eye. The distance from Nerwa to Majhotli, is 26 kms. as deposed by DW-1.\nWe find substance in the submission on behalf of the appellant, that the travelling time for the bus, in the hills, for this distance would be one hour or more. Prima facie, the prosecution story that the appellant was apprehended at Majhotli at 6.15 A.M.\nbecomes seriously doubtful if not impossible. The bus would have reached Majhotli at about 8.00 A.M. or thereafter only. The conclusion of the High Court that passage of time, and memory loss, were sufficient explanation for the time difference, is held to be perverse, and without proper consideration of Exhibit DX.\nPW-2, the independent witness has stated that he was stopped at Majhotli by the police at 10.30 A.M. and was allowed to leave after verification of his motor cycle papers. The witness has specifically denied that the appellant was apprehended in his presence and that any search, seizure and recovery was conducted in his presence. He had deposed that he was called to the police station at 1:00 P.M. and asked to sign the papers. The witness was declared hostile. This aspect has not been considered by the High Court, which proceeded on the only assumption that the signatures were admitted.\n 8. In a case of sudden recovery, independent witness may not be available. But if an independent witness is available, and the prosecution initially seeks to rely upon him, it cannot suddenly discard the witness because it finds him inconvenient, and place reliance upon police witnesses only. In the stringent nature of the provisions of the Act, the reverse burden of proof, the presumption of culpability under Section 35, and the presumption against the accused under Section 54, any reliance upon Section 114 of the Evidence Act in the facts of the present case, can only be at the risk of a fair trial to the accused.\nKaramjit Singh vs. State (Delhi Administration), AIR 2003 SC 1311, is distinguishable on its facts as independent witness had refused to sign because of the fear of terrorists. Likewise S.\n Jeevananthanan vs. State, 2004(5) SCC 230, also does not appear to be a case where independent witnesses were available.\n 9. The presumption against the accused of culpability under Section 35, and under Section 54 of the Act to explain possession satisfactorily, are rebuttable. It does not dispense with the obligation of the prosecution to prove the charge beyond all reasonable doubt. The presumptive provision with reverse burden of proof, does not sanction conviction on basis of preponderance of probability. Section 35 (2) provides that a fact can be said to have been proved if it is established beyond reasonable doubt and not on preponderance of probability. That the right of the accused to a fair trial could not be whittled down under the Act was considered in Noor Aga vs. State of Punjab, (2008) 16 SCC 417, observing:- \"58......An initial burden exists upon the prosecution and only when it stands satisfied, would the legal burden shift. Even then, the standard of proof required for the accused to prove his innocence is not as high as that of the prosecution. Whereas the standard of proof required to prove the guilt of the accused on the prosecution is \"beyond all reasonable doubt\" but it is \"preponderance of probability\" on the accused. If the prosecution fails to prove the foundational facts so as to attract the rigours of Section 35 of the Act, the actus reus which is possession of contraband by the accused cannot be said to have been established.\n 59. With a view to bring within its purview the requirements of Section 54 of the Act, element of possession of the contraband was essential so as to shift the burden on the accused. The provisions being exceptions to the general rule, the generality thereof would continue to be operative, namely, the element of possession will have to be proved beyond reasonable doubt.\"\n 10. In the facts of the present case, and the nature of evidence as discussed, the prosecution had failed to establish the foundational facts beyond all reasonable doubt. The special judge committed no error in acquitting the appellant. The High Court ought not to have interfered with the same. The submissions regarding non-compliance with Section 50 of the Act, or that the complainant could not be the investigating officer are not considered necessary to deal with in the facts of the case.\n 11. In Basappa (supra), it was observed that the High Court before setting aside an order of acquittal was required to record a finding that the conclusions of the Trial Court were so perverse and wholly unreasonable, so as not to be a plausible view by misreading and incorrect appreciation of evidence. The conclusions of the High Court in the facts of the present case are more speculative, based on conjectures and surmises, contrary to the weight of the evidence on record.\n 12. The order of the High Court is set aside. The acquittal of the appellant ordered by the Special Judge is restored. The appellant is set at liberty forthwith, unless wanted in any other case. The appeal is allowed.\n ........................................J.\n                             (L. Nageswara Rao) .......................................J.\n                                     (Navin Sinha) New Delhi, July 27, 2017''':
#       predefined_summary = requests.get('https://storage.googleapis.com/indianlegalbert/Rhetorical%20role/experiments/predefined_summary.txt').text
#       predefined_rhet_roles =  requests.get('https://storage.googleapis.com/indianlegalbert/Rhetorical%20role/experiments/predefined_rhet.json').json()
#       return predefined_summary,predefined_rhet_roles

#     preamble_txt,preamble_removed_txt  = split_preamble_judgement(input_txt)
#     cleaned_text = preamble_txt + preamble_removed_txt
#     custom_data = [  {"id": 1,"data": { "text": cleaned_text }}]
#     with open('datasets/custom_data.json','w') as file:
#       json.dump(custom_data,file)
    
#     !python infer_data_prep.py datasets/custom_data.json datasets/custom_processed_data.json
#     !python infer_new.py datasets/custom_processed_data.json datasets/custom_output.json datasets/model.pt

#     predictions = json.load(open('datasets/custom_output.json'))
#     sent_tags = []
#     annotation_list = predictions[0]['annotations'][0]['result']
#     for i,annotation in enumerate(annotation_list):
#       sent_tags.append((annotation['value']['text'],annotation['value']['labels'][0]))
#       if i < len(annotation_list)-1 and annotation_list[i+1]['value']['start'] > annotation['value']['end']:
#         sent_tags.append((cleaned_text[annotation['value']['end'] :annotation_list[i+1]['value']['start']],None))

#     ##### create summary for each rhetorical role
#     rheotrical_roles_to_summarize = ['FAC','RLC','ISSUE','ARG_PETITIONER','ARG_RESPONDENT','ANALYSIS','PRECEDENT_RELIED','PRECEDENT_NOT_RELIED','STA','RATIO','RPC']
    
#     try:
#       rhetorical_rolewise_text = concatenate_text_by_rhetorical_role(annotation_list)
#       legal_summarizer = SummaryGeneration(model="nsi319/legal-pegasus", tokenizer="nsi319/legal-pegasus")
      
#       generated_summaries_dict={} ##### key is rhetorical role and value is dict of {"summary":'fdsf...', "is_summarized":True}
#       for rhet_role, rhet_text in rhetorical_rolewise_text.items():
#         ######## create summary only if the text is long enough
#         if len(rhet_text)>1000:
#           generated_summaries = legal_summarizer.generate(rhet_text, token_max_length=1024)
#           generated_summaries_dict[rhet_role] = {"summary":generated_summaries[0]["level_1_summary"],"is_summarized":True}
#         else:
#           generated_summaries_dict[rhet_role] = {"summary":rhet_text,"is_summarized":False}
#       final_summary=''
#       for rhetorical_role in rheotrical_roles_to_summarize:
#         if generated_summaries_dict.get(rhetorical_role) is not None:
#           final_summary = final_summary + '#'*30+'\n' +rhetorical_role +" SUMMARY:\n" + generated_summaries_dict[rhetorical_role]['summary']+ "\n"+ '#'*30+'\n'
#     except Exception as e:
#       final_summary = "ERROR in creating summary, please try again.\n Error Description:" + str(e)

#     return final_summary,sent_tags

# input_txt = '''                                                         REPORTABLE\n\n  IN THE SUPREME COURT OF INDIA\n CRIMINAL APPELLATE JURISDICTION\n\nCRIMINAL APPEAL NO. 1053 OF 2016\n\nNARESH KUMAR alias NITU                            ..........APPELLANT\n                                                   ......RESPONDENT\n                                           Versus\nSTATE OF HIMACHAL PRADESH\n\n                                       JUDGMENT\n NAVIN SINHA, J.\n The acquittal of the appellant by the Special Judge, Shimla in Sessions Trial No.7-S/7/2012, from the charge under Sections 20 and 61 of the Narcotic Drugs and Psychotropic Substances Act, 1985 (hereinafter referred as `the Act') has been reversed by the High Court. The appellant has been sentenced to fifteen years imprisonment and fine of Rs.2,00,000/-. Thus the present appeal.\n 2. The appellant is stated to have been apprehended at Majhotli, by the police party, on suspicion, at about 6.15 A.M.\nafter he disembarked from the State public transport bus going from Nerwa to Chamunda. Two kilograms of Charas is stated to have been recovered from a bag in his possession in presence of PW-2, Sita Ram an independent witness. DW-1 Shayam Singh, the depot in-charge at Nerwa, and DW-2 Khem Raj, the conductor of the bus in question were examined as defence witnesses.\n 3. After consideration of the entirety of the evidence, particularly that of PW-2 and DW-2, and also noticing that PW-1, Constable Rakesh Kumar, an eye-witness to the incident, had not been mentioned as a witness in the seizure memo Exhibit PW-1/B, the Special Judge opined that two theories had emerged with regard to the accusations against the appellant. The appellant was acquitted, giving him the benefit of doubt.\n 4. The High Court reversed the acquittal, holding that PW-2 had admitted his signatures on Exhibit PW-1/B, the bag along with the narcotic, Ex.PW-2/A seal impression, Ex.PW-2/D the arrest memo and the Ex.PW-2/E personal search memo. No complaint had been lodged by the witness that he had been compelled by the police to sign the documents under pressure.\nThe statements of the official witnesses, PW-1 Rakesh Kumar and PW-6 Head Constable Parmanand, were trustworthy, inspiring confidence, and could not be rejected only on the ground that they were police personnel. Any discrepancy with regard to distance and travelling time between Nerwa and Majhotli could be attributed to memory loss with passage of time, and was not required to be with mathematical precision. The time with regard to purchase of bus ticket had not been established.\n 5. Learned counsel for the appellant submits that he has been falsely implicated. He was deboarded from the bus at Chopal after it arrived from Majhotli and the narcotics planted on him. There had been no recovery from him. The bus ticket evidently reveals that he boarded the bus at 6:51 A.M. The question of his being apprehended at 6:15 A.M. simply does not arise. The road distance from Nerwa to Majhotli was 26 kms. as deposed by DW-1. In the hills, it would have taken the bus at least one hour or more, to cover this distance. The bus could not have reached Majhotli till 8:00 A.M. or thereafter. PW-2, the independent witness, deposed that he was stopped by the police at about 10.30 A.M. at Majhotli and after checking his motor cycle papers was allowed to leave. He was called to the Police Station at 1.00 P.M. and asked to put his signatures on certain documents. The witness denied any search, seizure and recovery from the appellant in his presence. If an independent witness was available, and relied upon by the prosecution, his evidence could not be discarded without reason, to hold that the police version was the truth. Additional submissions were made with regard to non-compliance with Section 50 of the Act, as there was personal search also, and that the complainant himself could not be the investigating officer. Reliance was placed on Basappa vs. State of Karnataka, 2014 (5) SCC 154 that if two views were possible, the acquittal ought not to have been interfered with in appeal.\n 6. We have considered the submissions on behalf of the parties, and also examined the evidence and other materials on record.\n 7. The public bus, on which the appellant was traveling, was going from Nerwa to Chamunda. The ticket issued to the appellant Exhibit DX, proved by the bus Conductor DW-2, bears the time of issuance 6.51 A.M., visible to the naked eye. The distance from Nerwa to Majhotli, is 26 kms. as deposed by DW-1.\nWe find substance in the submission on behalf of the appellant, that the travelling time for the bus, in the hills, for this distance would be one hour or more. Prima facie, the prosecution story that the appellant was apprehended at Majhotli at 6.15 A.M.\nbecomes seriously doubtful if not impossible. The bus would have reached Majhotli at about 8.00 A.M. or thereafter only. The conclusion of the High Court that passage of time, and memory loss, were sufficient explanation for the time difference, is held to be perverse, and without proper consideration of Exhibit DX.\nPW-2, the independent witness has stated that he was stopped at Majhotli by the police at 10.30 A.M. and was allowed to leave after verification of his motor cycle papers. The witness has specifically denied that the appellant was apprehended in his presence and that any search, seizure and recovery was conducted in his presence. He had deposed that he was called to the police station at 1:00 P.M. and asked to sign the papers. The witness was declared hostile. This aspect has not been considered by the High Court, which proceeded on the only assumption that the signatures were admitted.\n 8. In a case of sudden recovery, independent witness may not be available. But if an independent witness is available, and the prosecution initially seeks to rely upon him, it cannot suddenly discard the witness because it finds him inconvenient, and place reliance upon police witnesses only. In the stringent nature of the provisions of the Act, the reverse burden of proof, the presumption of culpability under Section 35, and the presumption against the accused under Section 54, any reliance upon Section 114 of the Evidence Act in the facts of the present case, can only be at the risk of a fair trial to the accused.\nKaramjit Singh vs. State (Delhi Administration), AIR 2003 SC 1311, is distinguishable on its facts as independent witness had refused to sign because of the fear of terrorists. Likewise S.\n Jeevananthanan vs. State, 2004(5) SCC 230, also does not appear to be a case where independent witnesses were available.\n 9. The presumption against the accused of culpability under Section 35, and under Section 54 of the Act to explain possession satisfactorily, are rebuttable. It does not dispense with the obligation of the prosecution to prove the charge beyond all reasonable doubt. The presumptive provision with reverse burden of proof, does not sanction conviction on basis of preponderance of probability. Section 35 (2) provides that a fact can be said to have been proved if it is established beyond reasonable doubt and not on preponderance of probability. That the right of the accused to a fair trial could not be whittled down under the Act was considered in Noor Aga vs. State of Punjab, (2008) 16 SCC 417, observing:- \"58......An initial burden exists upon the prosecution and only when it stands satisfied, would the legal burden shift. Even then, the standard of proof required for the accused to prove his innocence is not as high as that of the prosecution. Whereas the standard of proof required to prove the guilt of the accused on the prosecution is \"beyond all reasonable doubt\" but it is \"preponderance of probability\" on the accused. If the prosecution fails to prove the foundational facts so as to attract the rigours of Section 35 of the Act, the actus reus which is possession of contraband by the accused cannot be said to have been established.\n 59. With a view to bring within its purview the requirements of Section 54 of the Act, element of possession of the contraband was essential so as to shift the burden on the accused. The provisions being exceptions to the general rule, the generality thereof would continue to be operative, namely, the element of possession will have to be proved beyond reasonable doubt.\"\n 10. In the facts of the present case, and the nature of evidence as discussed, the prosecution had failed to establish the foundational facts beyond all reasonable doubt. The special judge committed no error in acquitting the appellant. The High Court ought not to have interfered with the same. The submissions regarding non-compliance with Section 50 of the Act, or that the complainant could not be the investigating officer are not considered necessary to deal with in the facts of the case.\n 11. In Basappa (supra), it was observed that the High Court before setting aside an order of acquittal was required to record a finding that the conclusions of the Trial Court were so perverse and wholly unreasonable, so as not to be a plausible view by misreading and incorrect appreciation of evidence. The conclusions of the High Court in the facts of the present case are more speculative, based on conjectures and surmises, contrary to the weight of the evidence on record.\n 12. The order of the High Court is set aside. The acquittal of the appellant ordered by the Special Judge is restored. The appellant is set at liberty forthwith, unless wanted in any other case. The appeal is allowed.\n ........................................J.\n                             (L. Nageswara Rao) .......................................J.\n                                     (Navin Sinha) New Delhi, July 27, 2017'''

# color_map={"PREAMBLE": "LightCyan", "FAC": "Yellow","RLC":"LightSkyBlue",
# "ISSUE":"Aquamarine","ARG_PETITIONER":"LightGreen","ARG_RESPONDENT":"Lavender","ANALYSIS":"Thistle","STA":"PaleGoldenrod","PRE_RELIED":"YellowGreen","PRE_NOT_RELIED":"Gold",
# "RATIO":"Orange","RPC":"PeachPuff","NONE":"Linen" }


# ########## launch Gradio UI
# iface = gr.Interface(
#     predict_rhetorical_roles_and_create_summary,
#     [
#         gr.inputs.Textbox(
#             lines=20, default=input_txt)
#     ],
#     [gr.outputs.Textbox(label = 'AI Generated Summary'), gr.outputs.HighlightedText(color_map = color_map, label = 'Predicted Rhetorical Roles')],
#     description = "You can copy paste custom judgement text (E.g. https://indiankanoon.org/doc/181002261/) into input box and click submit. If you do not change the text in input box then results will be shown immediately. Else you will have to wait (3 to 15 minutes depending on length of input text) for results",
#     enable_queue=True)
# gradio_output = iface.launch()

# ########## play beep 
# from google.colab import output
# output.eval_js('new Audio("https://static.sfdict.com/audio/C07/C0702600.mp3").play()')

# ## launch UI in new tab
# js_script= "window.open('"+ gradio_output[2]+ "'"+',"_blank");'
# output.eval_js(js_script)

# %%
# import spacy
# spacy.require_gpu()
# nlp=spacy.load('en_core_web_trf')

# %%
# !pip freeze

# %%
#@title
# ####### function to predict rhetorical roles
# from data_prep import split_preamble_judgement
# def predict_rhetorical_roles(input_txt):
#     preamble_txt,preamble_removed_txt  = split_preamble_judgement(input_txt)
#     cleaned_text = preamble_txt + preamble_removed_txt
#     custom_data = [  {"id": 1,"data": { "text": cleaned_text }}]
#     with open('datasets/custom_data.json','w') as file:
#       json.dump(custom_data,file)
    
#     !python infer_data_prep.py datasets/custom_data.json datasets/custom_processed_data.json
#     !python infer_new.py datasets/custom_processed_data.json datasets/custom_output.json datasets/model.pt

#     predictions = json.load(open('datasets/custom_output.json'))
#     sent_tags = []
#     annotation_list = predictions[0]['annotations'][0]['result']
#     for i,annotation in enumerate(annotation_list):
#       sent_tags.append((annotation['value']['text'],annotation['value']['labels'][0]))
#       if i < len(annotation_list)-1 and annotation_list[i+1]['value']['start'] > annotation['value']['end']:
#         sent_tags.append((cleaned_text[annotation['value']['end'] :annotation_list[i+1]['value']['start']],None))

#     return sent_tags

# ### sample input data 
# input_txt = '''                                                         REPORTABLE\n\n  IN THE SUPREME COURT OF INDIA\n CRIMINAL APPELLATE JURISDICTION\n\nCRIMINAL APPEAL NO. 1053 OF 2016\n\nNARESH KUMAR alias NITU                            ..........APPELLANT\n                                                   ......RESPONDENT\n                                           Versus\nSTATE OF HIMACHAL PRADESH\n\n                                       JUDGMENT\n NAVIN SINHA, J.\n The acquittal of the appellant by the Special Judge, Shimla in Sessions Trial No.7-S/7/2012, from the charge under Sections 20 and 61 of the Narcotic Drugs and Psychotropic Substances Act, 1985 (hereinafter referred as `the Act') has been reversed by the High Court. The appellant has been sentenced to fifteen years imprisonment and fine of Rs.2,00,000/-. Thus the present appeal.\n 2. The appellant is stated to have been apprehended at Majhotli, by the police party, on suspicion, at about 6.15 A.M.\nafter he disembarked from the State public transport bus going from Nerwa to Chamunda. Two kilograms of Charas is stated to have been recovered from a bag in his possession in presence of PW-2, Sita Ram an independent witness. DW-1 Shayam Singh, the depot in-charge at Nerwa, and DW-2 Khem Raj, the conductor of the bus in question were examined as defence witnesses.\n 3. After consideration of the entirety of the evidence, particularly that of PW-2 and DW-2, and also noticing that PW-1, Constable Rakesh Kumar, an eye-witness to the incident, had not been mentioned as a witness in the seizure memo Exhibit PW-1/B, the Special Judge opined that two theories had emerged with regard to the accusations against the appellant. The appellant was acquitted, giving him the benefit of doubt.\n 4. The High Court reversed the acquittal, holding that PW-2 had admitted his signatures on Exhibit PW-1/B, the bag along with the narcotic, Ex.PW-2/A seal impression, Ex.PW-2/D the arrest memo and the Ex.PW-2/E personal search memo. No complaint had been lodged by the witness that he had been compelled by the police to sign the documents under pressure.\nThe statements of the official witnesses, PW-1 Rakesh Kumar and PW-6 Head Constable Parmanand, were trustworthy, inspiring confidence, and could not be rejected only on the ground that they were police personnel. Any discrepancy with regard to distance and travelling time between Nerwa and Majhotli could be attributed to memory loss with passage of time, and was not required to be with mathematical precision. The time with regard to purchase of bus ticket had not been established.\n 5. Learned counsel for the appellant submits that he has been falsely implicated. He was deboarded from the bus at Chopal after it arrived from Majhotli and the narcotics planted on him. There had been no recovery from him. The bus ticket evidently reveals that he boarded the bus at 6:51 A.M. The question of his being apprehended at 6:15 A.M. simply does not arise. The road distance from Nerwa to Majhotli was 26 kms. as deposed by DW-1. In the hills, it would have taken the bus at least one hour or more, to cover this distance. The bus could not have reached Majhotli till 8:00 A.M. or thereafter. PW-2, the independent witness, deposed that he was stopped by the police at about 10.30 A.M. at Majhotli and after checking his motor cycle papers was allowed to leave. He was called to the Police Station at 1.00 P.M. and asked to put his signatures on certain documents. The witness denied any search, seizure and recovery from the appellant in his presence. If an independent witness was available, and relied upon by the prosecution, his evidence could not be discarded without reason, to hold that the police version was the truth. Additional submissions were made with regard to non-compliance with Section 50 of the Act, as there was personal search also, and that the complainant himself could not be the investigating officer. Reliance was placed on Basappa vs. State of Karnataka, 2014 (5) SCC 154 that if two views were possible, the acquittal ought not to have been interfered with in appeal.\n 6. We have considered the submissions on behalf of the parties, and also examined the evidence and other materials on record.\n 7. The public bus, on which the appellant was traveling, was going from Nerwa to Chamunda. The ticket issued to the appellant Exhibit DX, proved by the bus Conductor DW-2, bears the time of issuance 6.51 A.M., visible to the naked eye. The distance from Nerwa to Majhotli, is 26 kms. as deposed by DW-1.\nWe find substance in the submission on behalf of the appellant, that the travelling time for the bus, in the hills, for this distance would be one hour or more. Prima facie, the prosecution story that the appellant was apprehended at Majhotli at 6.15 A.M.\nbecomes seriously doubtful if not impossible. The bus would have reached Majhotli at about 8.00 A.M. or thereafter only. The conclusion of the High Court that passage of time, and memory loss, were sufficient explanation for the time difference, is held to be perverse, and without proper consideration of Exhibit DX.\nPW-2, the independent witness has stated that he was stopped at Majhotli by the police at 10.30 A.M. and was allowed to leave after verification of his motor cycle papers. The witness has specifically denied that the appellant was apprehended in his presence and that any search, seizure and recovery was conducted in his presence. He had deposed that he was called to the police station at 1:00 P.M. and asked to sign the papers. The witness was declared hostile. This aspect has not been considered by the High Court, which proceeded on the only assumption that the signatures were admitted.\n 8. In a case of sudden recovery, independent witness may not be available. But if an independent witness is available, and the prosecution initially seeks to rely upon him, it cannot suddenly discard the witness because it finds him inconvenient, and place reliance upon police witnesses only. In the stringent nature of the provisions of the Act, the reverse burden of proof, the presumption of culpability under Section 35, and the presumption against the accused under Section 54, any reliance upon Section 114 of the Evidence Act in the facts of the present case, can only be at the risk of a fair trial to the accused.\nKaramjit Singh vs. State (Delhi Administration), AIR 2003 SC 1311, is distinguishable on its facts as independent witness had refused to sign because of the fear of terrorists. Likewise S.\n Jeevananthanan vs. State, 2004(5) SCC 230, also does not appear to be a case where independent witnesses were available.\n 9. The presumption against the accused of culpability under Section 35, and under Section 54 of the Act to explain possession satisfactorily, are rebuttable. It does not dispense with the obligation of the prosecution to prove the charge beyond all reasonable doubt. The presumptive provision with reverse burden of proof, does not sanction conviction on basis of preponderance of probability. Section 35 (2) provides that a fact can be said to have been proved if it is established beyond reasonable doubt and not on preponderance of probability. That the right of the accused to a fair trial could not be whittled down under the Act was considered in Noor Aga vs. State of Punjab, (2008) 16 SCC 417, observing:- \"58......An initial burden exists upon the prosecution and only when it stands satisfied, would the legal burden shift. Even then, the standard of proof required for the accused to prove his innocence is not as high as that of the prosecution. Whereas the standard of proof required to prove the guilt of the accused on the prosecution is \"beyond all reasonable doubt\" but it is \"preponderance of probability\" on the accused. If the prosecution fails to prove the foundational facts so as to attract the rigours of Section 35 of the Act, the actus reus which is possession of contraband by the accused cannot be said to have been established.\n 59. With a view to bring within its purview the requirements of Section 54 of the Act, element of possession of the contraband was essential so as to shift the burden on the accused. The provisions being exceptions to the general rule, the generality thereof would continue to be operative, namely, the element of possession will have to be proved beyond reasonable doubt.\"\n 10. In the facts of the present case, and the nature of evidence as discussed, the prosecution had failed to establish the foundational facts beyond all reasonable doubt. The special judge committed no error in acquitting the appellant. The High Court ought not to have interfered with the same. The submissions regarding non-compliance with Section 50 of the Act, or that the complainant could not be the investigating officer are not considered necessary to deal with in the facts of the case.\n 11. In Basappa (supra), it was observed that the High Court before setting aside an order of acquittal was required to record a finding that the conclusions of the Trial Court were so perverse and wholly unreasonable, so as not to be a plausible view by misreading and incorrect appreciation of evidence. The conclusions of the High Court in the facts of the present case are more speculative, based on conjectures and surmises, contrary to the weight of the evidence on record.\n 12. The order of the High Court is set aside. The acquittal of the appellant ordered by the Special Judge is restored. The appellant is set at liberty forthwith, unless wanted in any other case. The appeal is allowed.\n ........................................J.\n                             (L. Nageswara Rao) .......................................J.\n                                     (Navin Sinha) New Delhi, July 27, 2017'''


# color_map={"PREAMBLE": "LightCyan", "FAC": "Yellow","RLC":"LightSkyBlue",
# "ISSUE":"Aquamarine","ARG_PETITIONER":"LightGreen","ARG_RESPONDENT":"Lavender","ANALYSIS":"Thistle","STA":"PaleGoldenrod","PRE_RELIED":"YellowGreen","PRE_NOT_RELIED":"Gold",
# "RATIO":"Orange","RPC":"PeachPuff","NONE":"Linen" }


# ########## launch Gradio UI
# iface = gr.Interface(
#     predict_rhetorical_roles,
#     [
#         gr.inputs.Textbox(
#             lines=20, default=input_txt)
#     ],
#     gr.outputs.HighlightedText(color_map))
# gradio_output = iface.launch()

# ########## play beep 
# from google.colab import output
# output.eval_js('new Audio("https://static.sfdict.com/audio/C07/C0702600.mp3").play()')
